# %%
import nltk
from nltk.corpus import brown
import re
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from string import punctuation
from os import path, pardir
import sys
import pandas as pd
from pandas import DataFrame, Series
import numpy as np
from bs4 import BeautifulSoup
import re
from collections import defaultdict

# %%
data = pd.io.pickle.read_pickle(path.join(pardir, 'data', 'job_descriptions.pkl'))
data.head()
# Out:
#                                             ApplyURL BasicJobBranding  \
# 0  http://api.careerbuilder.com/v1/application/ap...              NaN
# 1  http://api.careerbuilder.com/v1/application/ap...              NaN
# 2  http://api.careerbuilder.com/v1/application/ap...              NaN
# 3  http://api.careerbuilder.com/v1/application/ap...              NaN
# 4  http://api.careerbuilder.com/v1/application/ap...              NaN
#
#     BeginDate                         BlankApplicationServiceURL  \
# 0  10/12/2014  http://api.careerbuilder.com/v1/application/bl...
# 1  10/12/2014  http://api.careerbuilder.com/v1/application/bl...
# 2  10/12/2014  http://api.careerbuilder.com/v1/application/bl...
# 3  10/12/2014  http://api.careerbuilder.com/v1/application/bl...
# 4  10/12/2014  http://api.careerbuilder.com/v1/application/bl...
#
#                                     Categories    CategoriesCodes  \
# 0    Sales,  Business Development,  Management  JN011,JN019,JN037
# 1                                     Training              JN032
# 2                                        Sales              JN011
# 3  Construction,  Sales,  Business Opportunity  JN043,JN011,JN059
# 4                                        Sales              JN011
#
#                     Company           CompanyDID  \
# 0  Largent & Associates LLC  CHS3SX6C15LNF4HRQ6Q
# 1                       NaN                  NaN
# 2                    Sunrun  CHQ010614MZ6J2S07V4
# 3        The Master's Touch  CHM2YN5WGB2C3NX62RY
# 4                    Sunrun  CHQ010614MZ6J2S07V4
#
#                                    CompanyDetailsURL  \
# 0  http://www.careerbuilder.com/jobs/company/chs3...
# 1                                                NaN
# 2  http://www.careerbuilder.com/jobs/company/chq0...
# 3  http://www.careerbuilder.com/jobs/company/chm2...
# 4  http://www.careerbuilder.com/jobs/company/chq0...
#
#                                      CompanyImageURL  \
# 0  http://emj.icbdr.com/MediaManagement/2G/MVC6X3...
# 1                                                NaN
# 2  http://emj.icbdr.com/MediaManagement/G0/MVM81W...
# 3  http://emj.icbdr.com/MediaManagement/DN/MVD3D5...
# 4  http://emj.icbdr.com/MediaManagement/G0/MVM81W...
#
#                                  CompanyJobSearchURL  \
# 0  http://www.careerbuilder.com/jobs/company/chs3...
# 1                                                NaN
# 2  http://www.careerbuilder.com/jobs/company/chq0...
# 3  http://www.careerbuilder.com/jobs/company/chm2...
# 4  http://www.careerbuilder.com/jobs/company/chq0...
#
#                                  ContactInfoEmailURL ContactInfoFax  \
# 0  http://www.careerbuilder.com/jobseeker/applyon...            NaN
# 1  http://www.careerbuilder.com/jobseeker/applyon...            NaN
# 2  http://www.careerbuilder.com/jobseeker/applyon...            NaN
# 3  http://www.careerbuilder.com/jobseeker/applyon...            NaN
# 4  http://www.careerbuilder.com/jobseeker/applyon...            NaN
#
#         ContactInfoName ContactInfoPhone CustomApplyType                  DID  \
# 0  Largent & Associates              NaN          CANONE  JHL4PY5YCYWRKR5SR63
# 1                   NaN              NaN          CANONE  J3H6HZ6HJ4RMVWCG7HZ
# 2                   NaN              NaN          CANONE  J3H3BC6PGK27KG7YZLN
# 3         Dustin Nelson     623-889-0313          CANONE  JHR71P6BGWQYFCSN5ZW
# 4                   NaN              NaN          CANONE  J3H5FV6N2RZXBQKJ2ZZ
#
#   DegreeRequired DegreeRequiredCode        DisplayJobID
# 0  4 Year Degree               DR32  495 Sales Dir West ...
# 1  4 Year Degree               DR32            US-27377 ...
# 2  Not Specified               DRNS                1069 ...
# 3  Not Specified               DRNS                 NaN ...
# 4  4 Year Degree               DR32                 732 ...
#
# [5 rows x 66 columns]

# %%
len(data)
# Out:
# 5043

# %% [markdown]
# Create a simplified df with just the DID and the description

# %%
data.columns
# Out:
# Index([u'ApplyURL', u'BasicJobBranding', u'BeginDate', u'BlankApplicationServiceURL', u'Categories', u'CategoriesCodes', u'Company', u'CompanyDID', u'CompanyDetailsURL', u'CompanyImageURL', u'CompanyJobSearchURL', u'ContactInfoEmailURL', u'ContactInfoFax', u'ContactInfoName', u'ContactInfoPhone', u'CustomApplyType', u'DID', u'DegreeRequired', u'DegreeRequiredCode', u'DisplayJobID', u'Division', u'EmploymentType', u'EmploymentTypeCode', u'EndDate', u'ExperienceRequired', u'ExperienceRequiredCode', u'ExternalApplication', u'HasQuestionnaire', u'IndustryCodes', u'JobDescription', u'JobRequirements', u'JobTitle', u'LocationCity', u'LocationCountry', u'LocationFormatted', u'LocationLatitude', u'LocationLongitude', u'LocationMetroCity', u'LocationPostalCode', u'LocationState', u'LocationStreet1', u'LocationStreet2', u'ManagesOthers', u'ManagesOthersCode', u'ManagesOthersString', u'ModifiedDate', u'ONetCode', u'PayBonus.Money.Amount', u'PayBonus.Money.CurrencyCode', u'PayBonus.Money.FormattedAmount', u'PayCommission.Money.Amount', u'PayCommission.Money.CurrencyCode', u'PayCommission.Money.FormattedAmount', u'PayHigh.Money.Amount', u'PayHigh.Money.CurrencyCode', u'PayHigh.Money.FormattedAmount', u'PayHighLowFormatted', u'PayLow.Money.Amount', u'PayLow.Money.CurrencyCode', u'PayLow.Money.FormattedAmount', u'PayOther', u'PayPer', u'PrinterFriendlyURL', u'RelocationCovered', u'TravelRequired', u'TravelRequiredCode'], dtype='object')

# %%
def asciiEncode(row):
    return row.encode('ascii')

# %%
post = data[['DID', 'JobDescription']]
post.set_index('DID', inplace=True)
post.columns = ['raw_text']
# post['raw_text'] = post.raw_text.map(lambda x: x.encode('ascii', 'ignore'))
# post.head()

# %% [markdown]
# Add a column with better-formed HTML

# %%
post['html'] = post.raw_text.map(lambda x: BeautifulSoup(x).getText())
# post.head()

# %% [markdown]
# Add a column with just the text (adapted from: http://stackoverflow.com/questions/10524387/beautifulsoup-get-text-does-not-strip-all-tags-and-javascript)

# %%
def visible_text(element):
    if element.parent.name in ['style', 'script', '[document]', 'head', 'title']:
        return ''
    #get rid of tags
    result = re.sub('<br>|<br \/>|<p\/?>|<\/?li>', '\n', str(element.encode('ascii', 'ignore')))
    result = re.sub('<.*?>', ' ', result, flags=re.DOTALL)
    #add single quotes
    result = re.sub('&rsquo;', "'", result)
    #get rid of extra spaces, html spaces, and bullets
    result = re.sub(' {2,}|&nbsp;|&bull;', ' ', result)
    #replace multiple newlines with single newline
    result = re.sub('\s{2,}|\t', '\n', result)
    #add in double quotes
    result = re.sub('&ldquo;', '"', result)
    result = re.sub('&rdquo;', '"', result)
    result = re.sub('&rdquo;', '"', result)
    return result

# %%
def rawToText(description):
    soup = BeautifulSoup(description)
    texts = soup.findAll(text=True)
    visible_elements = [visible_text(elem) for elem in texts]
    text = ''.join(visible_elements)
    return text

# %%
post['text'] = post.raw_text.apply(rawToText)
# post.head()

# %% [markdown]
# Add a column for a list of sentences

# %%
post['sents'] = post.text.map(lambda x: nltk.sent_tokenize(x))

# %% [markdown]
# Further split sentences on new lines

# %%
def splitNewLine(sents):
    final_sents = []
    for sent in sents:
        sub_sents = sent.split('\n')
        for sub in sub_sents:
            if sub != '':
                final_sents.append(sub)
    return final_sents

def splitSemicolon(sents):
    final_sents = []
    for sent in sents:
        sub_sents = sent.split(';')
        for sub in sub_sents:
            if sub != '':
                final_sents.append(sub)
    return final_sents

# %%
post['sents'] = post['sents'].map(splitNewLine)
post['sents'] = post['sents'].map(splitSemicolon)

# %%
post.sents[51]
# Out:
# ['We are looking to fill',
#  'entry-level',
#  'sales and customer service positions.',
#  'Our outsourced consulting firm provides customer acquisition and customer retention for Fortune 100 and 500 clients.',
#  'High achievers, we are looking for you!',
#  'We pride ourselves on our competitive spirit, and balance it with a fun and positive family oriented work environment.',
#  'Our culture promotes constant personal and professional growth, based on our values of integrity, work-ethic, and ambition.',
#  'We are now striving to attract and train the most capable and skilled individuals to help us acquire new clients, grow into new markets, and develop new campaigns.',
#  'We provide full training and career advancement.']

# %% [markdown]
# Add a column with list (sentences) of lists (words)

# %%
post['words'] = post.sents.map(lambda x: [nltk.word_tokenize(sent) for sent in x])

# %%
# Training on all brown sentences, excluding news corpus
brown_tagged_sents = brown.tagged_sents(categories=['news', 'adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies',
'humor', 'learned', 'lore', 'mystery', 'religion', 'reviews', 'romance',
'science_fiction'])

job_verbs = [[('Maintain', 'VB')], [('Maintains', 'VBZ')], [('Maintaining', 'VBG')],
             [('Ensure', 'VB')], [('Ensures', 'VBZ')], [('Ensuring', 'VBG')],
             [('Perform', 'VB')], [('Performs', 'VBZ')], [('Performing', 'VBG')],
             [('Manage', 'VB')], [('Manages', 'VBZ')], [('Managing', 'VBG')],
             [('Provide', 'VB')], [('Provides', 'VBZ')], [('Providing', 'VBG')],
             [('Assist', 'VB')], [('Assists', 'VBZ')], [('Assisting', 'VBG')],
             [('Prepare', 'VB')], [('Prepares', 'VBZ')], [('Preparing', 'VBG')],
             [('Participate', 'VB')], [('Participates', 'VBZ')], [('Participating', 'VBG')],
             [('Develop', 'VB')], [('Develops', 'VBZ')], [('Developing', 'VBG')],
             [('Understand', 'VB')], [('Understands', 'VBZ')], #Understanding? N
             [('Communicate', 'VB')], [('Communicates', 'VBZ')], [('Communicating', 'VBG')],
             [('Coordinate', 'VB')], [('Coordinates', 'VBZ')], [('Coordinating', 'VBG')],
             [('Complete', 'VB')], [('Completes', 'VBZ')],
             [('Create', 'VB')], [('Creates', 'VBZ')], [('Creating', 'VBG')],
             [('Review', 'VB')], [('Reviews', 'VBZ')],
             [('Receive', 'VB')], [('Receives', 'VBZ')], [('Receiving', 'VBG')],
             [('Analyze', 'VB')], [('Analyzes', 'VBZ')], [('Analyzing', 'VBG')],
             [('Demonstrate', 'VB')], [('Demonstrates', 'VBZ')], [('Demonstrating', 'VBG')],
             [('Interact', 'VB')], [('Interacts', 'VBZ')], [('Interacting', 'VBG')],
             [('Adhere', 'VB')], [('Adheres', 'VBZ')], [('Adhering', 'VBG')],
             [('Visit', 'VB')], [('Visiting', 'VBG')],
             [('Lead', 'VB')], [('Leads', 'VBZ')], # Leading? adj
             [('Monitor', 'VB')], [('Monitors', 'VBZ')], [('Monitoring', 'VBG')],
             [('Sell', 'VB')], [('Sells', 'VBZ')], [('Selling', 'VBG')]
             ]

all_tagged_sents = job_verbs + brown_tagged_sents

def create_data_sets():
    size = int(len(all_tagged_sents) * 0.9)
    train_sents = all_tagged_sents[:size]
    test_sents = all_tagged_sents[size:]
    return train_sents, test_sents
train_sents, test_sents = create_data_sets()

def build_backoff_tagger (train_sents):
    t0 = nltk.DefaultTagger('NN')
    t1 = nltk.UnigramTagger(train_sents, backoff=t0)
    t2 = nltk.BigramTagger(train_sents, backoff=t1)
    return t2
ngram_tagger = build_backoff_tagger(train_sents)
print "%0.3f" % ngram_tagger.evaluate(test_sents)
# Out:
# 0.913

# %% [markdown]
# Do default pos tagging on the words

# %%
post['ngram_tags'] = post.words.map(lambda x: [ngram_tagger.tag(word) for word in x])

# post.words.map(lambda x: [nltk.pos_tag(sent) for sent in x])
post.ngram_tags
# Out:
# DID
# JHL4PY5YCYWRKR5SR63    [[(Divisional, NN), (Sales, NNS), (Director, N...
# J3H6HZ6HJ4RMVWCG7HZ    [[(Field, NN-TL), (Training, NN-TL), (Speciali...
# J3H3BC6PGK27KG7YZLN    [[(FIELD, NN), (MARKETING, NN), (TRAINER, NN)]...
# JHR71P6BGWQYFCSN5ZW    [[(Click, NN), (on, IN), (the, AT), (LEARN, NN...
# J3H5FV6N2RZXBQKJ2ZZ    [[(Director, NN-TL), (,, ,), (FP, NN), (&, CC)...
# J3J60N74PNSP7K0V6FT    [[(General, NN-TL), (Manager, NN-TL)], [(Disco...
# J3F3KM63N1PFWC3S1XW    [[(Sales, NNS), (and, CC), (Service, NN-TL), (...
# J3G3XF703CPJ1YQHK21    [[(Ref, NN), (ID, NN), (:, :), (64953, NN)], [...
# J3J2PS748NQ6K7M45DD    [[(Ref, NN), (ID, NN), (:, :), (64954, NN)], [...
# J3J1ZY6ZS51Z7D6WHRY    [[(AML, NN), (Audit, NN), (Senior, JJ-TL), (Ma...
# J3H189609GP9ZT94402    [[(Sodexo, NN), (Campus, NN-TL), (Services, NN...
# JHN3235XTYSDRFNZ986    [[(*******************************************...
# JHM5W360403011QF5R9    [[(Successful, JJ), (candidate, NN), (for, IN)...
# J3H4596CV8J491NWB7Q    [[(Summary:, NN)], [(Supports, VBZ-HL), (innov...
# JB738Z61B91XRTX3V4F    [[(THE, NN), (POSITION, NN)], [(Parachute, NN)...
# ...
# J3J4BB748Z5HWSYQG71    [[(The, AT), (Army, NN-TL), (Reserve, NN-TL), ...
# J3G76H5YS9K56Y7XMJS    [[(Bringing, NN), (Compassionate, NN), (Care, ...
# J3J3SR6PL6RHZCP0BGH    [[(Some, DTI), (of, IN), (the, AT), (most, QL)...
# J3J3PZ76TJXXP7MBNLQ    [[(Customer, NN), (Service, NN-TL), (,, ,), (A...
# J3G7YZ6P64YJVBKXML7    [[(Some, DTI), (of, IN), (the, AT), (most, QL)...
# J3H1JV5Y04FXGZC1X0Q    [[(Customer, NN), (Service, NN-TL), (,, ,), (A...
# J3G5SL6BTW6SMRKFXXL    [[(Accounting, VBG), (Principals, NNS), (curre...
# JHS69Q62KCGJTQN67MR    [[(Manager, NN-TL), (Global, NN), (Regulatory,...
# JHS5QQ6MVKRSHNLPCM7    [[(Req, NN), (:, :), (1459, NN)], [(Title, NN-...
# JHM7NM732NHQL8SBKBQ    [[(Req, NN), (#, NN), (:, :), (1451, NN)], [(T...
# JHT3XG6BGH98HJSJCW8    [[(Tavant, NN), (Technologies, NN), (is, BEZ),...
# JHL5GB63Z50RJCNSY18    [[(Seeking, VBG), (an, AT), (A/R, NN), (Specia...
# JHT87K69M3X7628D6R0    [[(Immediate, NN), (need, MD), (for, IN), (a, ...
# J3H7ZS64RLMH4D3MLHS    [[(Join, VB), (Us, PPO-TL), (!, .)], [(We, PPS...
# J3H7C17910D5Q7MG416    [[(Position, NN), (Summary, NN-TL)], [(The, AT...
# Name: ngram_tags, Length: 5043, dtype: object

# %%
flat_tagged_sents = [item for sublist in post.ngram_tags.values for item in sublist]

# %%
def freq_normed_bigrams(sents):
    wnl = WordNetLemmatizer()
    
    tagged_POS_sents = [item for sublist in sents for item in sublist]
    
    normed_tagged_words = [wnl.lemmatize(word[0].lower()) for sent in tagged_POS_sents
                           for word in sent 
                           if word[0].lower() not in nltk.corpus.stopwords.words('english')
                           and word[0] not in punctuation
                           and not re.search(r'''^[\.,;"'?!():\-_`]+$''', word[0])]
#                            and word[1].startswith('N')]

    top_bigrams = nltk.FreqDist(nltk.bigrams(normed_tagged_words)).items()[:40]
    print '%-26s' % 'Word 1', '%-26s' % 'Word 2', '%-26s' % 'Freq'
    for ((word1, word2), freq) in top_bigrams:
        print '%-26s' % word1, '%-26s' % word2, '%-26s' % freq

# %%
freq_normed_bigrams(post.ngram_tags.values)
# Out:
# Word 1                     Word 2                     Freq
# customer                   service                    1853
# san                        francisco                  792
# communication              skill                      713
# team                       member                     652
# year                       experience                 601
# work                       environment                564
# equal                      opportunity                548
# ability                    work                       538
# opportunity                employer                   533
# medical                    dental                     517
# retail                     sale                       506
# policy                     procedure                  504
# dental                     vision                     489
# sale                       representative             488
# product                    service                    484
# job                        description                442
# 401                        k                          422
# must                       able                       413
# customer                   experience                 404
# united                     state                      397
# skill                      ability                    396
# click                      email                      377
# email                      resum                      376
# store                      manager                    354
# training                   program                    342
# ideal                      candidate                  341
# best                       practice                   340
# tuition                    reimbursement              339
# life                       insurance                  332
# work                       closely                    332
# entry                      level                      318
# every                      day                        317
# project                    management                 316
# bay                        area                       314
# san                        jose                       305
# qualified                  applicant                  304
# join                       team                       297
# benefit                    package                    294
# include                    limited                    294
# management                 team                       294

# %%
def get_verbs(tagged_sents):
    verbs = []
    for sent in tagged_sents:
        for word in sent:
            if word[1].startswith('VB'):
                verbs.append(word[0].lower())
    return nltk.FreqDist(verbs).keys()[:20] # use 20 most common verbs

def vp_chunker(sentence):
    grammar = r'''
        VP:
            {<V.*><AT|IN|JJ|CD>+<N.*>+} 
        '''
    cp = nltk.RegexpParser(grammar)
    return cp.parse(sentence)

def test_chunker(sentence, verb_list):
    tree = vp_chunker(sentence)
    VPs = []
    for subtree in tree.subtrees():
        if subtree.node == 'VP': 
            leaf = [leaf[0] for leaf in subtree.leaves()]
            for verb in verb_list:
                if verb in leaf:
                    VPs.append(' '.join(leaf))
    return VPs

def fd_chunked(sents):    
    tagged_POS_sents = [item for sublist in sents for item in sublist]
    VPs = []
    verb_list = get_verbs(tagged_POS_sents)
    for sent in tagged_POS_sents:
        for verb in verb_list:
            obj = test_chunker(sent, verb_list)
            if obj:
                for w in obj:
                    VPs.append(w)
    fd_VPs = nltk.FreqDist(VPs).items()[:60]
    
    print '%-36s' % 'Chunk','%-26s' % 'Freq'
    for (chunk, freq) in fd_VPs:
        print '%-36s' % chunk, '%-26s' % freq

# %%
fd_chunked(post.ngram_tags.values)
# Out:
# Chunk                                Freq
# make a difference                    2080
# looking for to work                  1520
# meet the needs                       1240
# provide critical market feedback     1220
# work in an industry                  1220
# perform the essential functions      1000
# make an impact                       940
# based on performance                 920
# provide a superior level             780
# develop a plan                       760
# looking for a career                 700
# work with 99 of the Fortune          700
# looking for an opportunity           600
# make the world                       600
# based in San Francisco               560
# assigned by management               540
# looking for individuals              500
# providing an outstanding Branded Customer Experience 480
# manage multiple projects             440
# providing outstanding customer service 440
# make true 1:1 communication          420
# looking for a part-time Product Demonstrator 400
# looking for a prosperous occupation  400
# looking for in an employer           400
# looking for people                   400
# providing powerful marketing solutions 400
# work in multiple departments         400
# working with people                  400
# based on experience                  360
# fosters a positive work environment  360
# make true 1:1 engagement             340
# provide a level                      340
# provide excellent career advancement potential 340
# working under the supervision        340
# assist in rehabilitation             320
# providing direct patient care        320
# working with computers               320
# assigned by Management               300
# ensure maximum productivity          300
# join a team                          300
# work with great people               300
# include 12 divisions                 280
# looking for a great sales opportunity 280
# looking for candidates               280
# work on todays                       280
# work on weekends                     280
# working in a fast-paced              280
# assist in the development            260
# based upon individual performance    260
# providing exceptional customer service 260
# work in a healthcare setting         260
# assigned by supervisor               240
# join a company                       240
# join the movement                    240
# manage multiple priorities           240
# provide optimal customer service     240
# providing superior customer service  240
# work from home                       240
# work under pressure                  240
# work with talented peers             240

# %%
def freq_normed_unigrams(sents):
    wnl = WordNetLemmatizer() # to get word stems
    
    tagged_POS_sents = [item for sublist in sents for item in sublist]
    
    normed_tagged_words = [wnl.lemmatize(word[0].lower()) for sent in tagged_POS_sents
                           for word in sent 
                           if word[0].lower() not in nltk.corpus.stopwords.words('english')
                           and word[0] not in punctuation # remove punctuation
                           and not re.search(r'''^[\.,;"'?!():\-_`]+$''', word[0])
                           and word[1].startswith('N')]  # include only nouns

    top_normed_unigrams = nltk.FreqDist(normed_tagged_words).keys()[:40]
    return top_normed_unigrams

def categories_from_hypernyms(sents):
    termlist = freq_normed_unigrams(sents) # get top unigrams
    hypterms = []
    hypterms_dict = defaultdict(list)
    for term in termlist:                  # for each term
        s = wn.synsets(term.lower(), 'n')  # get its nominal synsets
        for syn in s:                      # for each lemma synset
            for hyp in syn.hypernyms():    # It has a list of hypernyms
                hypterms = hypterms + [hyp.name]      # Extract the hypernym name and add to list
                hypterms_dict[hyp.name].append(term)  # Extract examples and add them to dict
    hypfd = nltk.FreqDist(hypterms)
    for (name, count) in hypfd.items()[:25]:
        print name, '({0})'.format(count)
        print '\t', ', '.join(set(hypterms_dict[name]))
        print

# %%
categories_from_hypernyms(post.ngram_tags.values)
# Out:
# activity.n.01 (9)
# 	training, service, business, process, support, work, job, position
#
# time_period.n.01 (5)
# 	time, year
#
# cognition.n.01 (4)
# 	process, information, ability
#
# work.n.01 (4)
# 	project, job, service
#
# body_part.n.01 (3)
# 	process, system, area
#
# occupation.n.01 (3)
# 	career, position, work
#
# point.n.02 (3)
# 	position
#
# ability.n.02 (2)
# 	skill
#
# aid.n.02 (2)
# 	support, service
#
# arrangement.n.03 (2)
# 	design, plan
#
# collection.n.01 (2)
# 	information, data
#
# consumer.n.01 (2)
# 	customer, client
#
# idea.n.01 (2)
# 	program, plan
#
# method.n.01 (2)
# 	system, solution
#
# plan.n.01 (2)
# 	project, design
#
# product.n.02 (2)
# 	job, work
#
# resource.n.01 (2)
# 	support
#
# selling.n.01 (2)
# 	sale
#
# social_control.n.01 (2)
# 	management, responsibility
#
# unit.n.03 (2)
# 	company, team
#
# accommodation.n.05 (1)
# 	service
#
# accumulation.n.04 (1)
# 	store
#
# accusation.n.01 (1)
# 	information
#
# acting.n.01 (1)
# 	business
#
# administration.n.02 (1)
# 	management

# %%
[item for sublist in post.ngram_tags.values for item in sublist]
# Out:
# [[('Divisional', 'NN'),
#   ('Sales', 'NNS'),
#   ('Director', 'NN-TL'),
#   (',', ','),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL')],
#  [('Are', 'BER'),
#   ('you', 'PPSS'),
#   ('looking', 'VBG'),
#   ('for', 'IN'),
#   ('a', 'AT'),
#   ('sales', 'NNS'),
#   ('management', 'NN'),
#   ('position', 'NN'),
#   ('?', '.')],
#  [('Do', 'DO'),
#   ('you', 'PPSS'),
#   ('have', 'HV'),
#   ('current', 'JJ'),
#   ('experience', 'NN'),
#   ('leading', 'VBG'),
#   ('direct', 'JJ'),
#   ('sales', 'NNS'),
#   ('reps', 'NNS'),
#   ('and', 'CC'),
#   ('distributors', 'NNS'),
#   ('selling', 'VBG'),
#   ('non-commodity', 'NN'),
#   ('technical', 'JJ'),
#   ('products', 'NNS'),
#   ('and', 'CC'),
#   ('solutions', 'NNS'),
#   ('to', 'TO'),
#   ('multiple', 'JJ'),
#   ('industries', 'NNS'),
#   ('?', '.')],
#  [('Do', 'DO'),
#   ('you', 'PPSS'),
#   ('believe', 'VB'),
#   ('sales', 'NNS'),
#   ('people', 'NNS'),
#   ('make', 'VB'),
#   ('sales', 'NNS'),
#   ('to', 'TO'),
#   ('happen', 'VB'),
#   ('or', 'CC'),
#   ('do', 'DO'),
#   ('sales', 'NNS'),
#   ('happen', 'VB'),
#   ('to', 'TO'),
#   ('sales', 'NNS'),
#   ('people', 'NNS'),
#   ('?', '.')],
#  [('Do', 'DO'),
#   ('you', 'PPSS'),
#   ('agree', 'VB'),
#   ('that', 'CS'),
#   ('as', 'CS'),
#   ('a', 'AT'),
#   ('sales', 'NNS'),
#   ('leader', 'NN'),
#   ('it', 'PPS'),
#   ('is', 'BEZ'),
#   ('your', 'PP$'),
#   ('responsibility', 'NN'),
#   ('to', 'IN'),
#   ('constantly', 'RB'),
#   ('monitor', 'NN'),
#   ('and', 'CC'),
#   ('evaluate', 'VB'),
#   ('the', 'AT'),
#   ('quality', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('sales', 'NNS'),
#   ('pipeline', 'NN'),
#   ('?', '.')],
#  [('Are', 'BER'),
#   ('you', 'PPSS'),
#   ('effective', 'JJ'),
#   ('keeping', 'VBG'),
#   ('your', 'PP$'),
#   ('direct', 'JJ'),
#   ('reports', 'NNS'),
#   ('and', 'CC'),
#   ('distributors', 'NNS'),
#   ('focused', 'VBN'),
#   (',', ','),
#   ('thinking', 'VBG'),
#   ('strategically', 'RB'),
#   (',', ','),
#   ('acting', 'VBG'),
#   ('with', 'IN'),
#   ('urgency', 'NN'),
#   ('and', 'CC'),
#   ('asking', 'VBG'),
#   ('for', 'IN'),
#   ('and', 'CC'),
#   ('closing', 'VBG'),
#   ('the', 'AT'),
#   ('business', 'NN'),
#   ('?', '.')],
#  [('As', 'CS'),
#   ('a', 'AT'),
#   ('sales', 'NNS'),
#   ('leader/manager', 'NN'),
#   (',', ','),
#   ('how', 'WRB'),
#   ('do', 'DO'),
#   ('you', 'PPSS'),
#   ('communicate', 'VB'),
#   ('and', 'CC'),
#   ('demonstrate', 'VB'),
#   ('a', 'AT'),
#   ('genuine', 'JJ'),
#   ('passion', 'NN'),
#   ('for', 'IN'),
#   ('professional', 'JJ'),
#   ('excellence', 'NN'),
#   (',', ','),
#   ('high', 'JJ'),
#   ('ethical', 'JJ'),
#   ('standards', 'NNS'),
#   ('including', 'IN'),
#   ('individual', 'JJ'),
#   ('accountability', 'NN'),
#   ('and', 'CC'),
#   ('the', 'AT'),
#   ('importance', 'NN'),
#   ('of', 'IN'),
#   ('working', 'VBG'),
#   ('collaboratively', 'NN'),
#   ('?', '.')],
#  [('Do', 'DO'),
#   ('you', 'PPSS'),
#   ('have', 'HV'),
#   ('sales', 'NNS'),
#   ('management', 'NN'),
#   ('experience', 'NN'),
#   ('of', 'IN'),
#   ('at', 'IN'),
#   ('least', 'AP'),
#   ('5', 'CD'),
#   ('direct', 'JJ'),
#   ('reports', 'NNS'),
#   ('?', '.')],
#  [('Does', 'DOZ'),
#   ('your', 'PP$'),
#   ('sales', 'NNS'),
#   ('management', 'NN'),
#   ('experience', 'NN'),
#   ('include', 'VB'),
#   ('responsibility', 'NN'),
#   ('for', 'IN'),
#   ('direct', 'JJ'),
#   ('outside', 'RB'),
#   ('sales', 'NNS'),
#   ('people', 'NNS'),
#   ('in', 'IN'),
#   ('remote', 'JJ'),
#   ('locations', 'NNS'),
#   (',', ','),
#   ('working', 'VBG'),
#   ('from', 'IN'),
#   ('offices', 'NNS'),
#   ('in', 'IN'),
#   ('their', 'PP$'),
#   ('homes', 'NNS'),
#   ('?', '.')],
#  [('Does', 'DOZ'),
#   ('your', 'PP$'),
#   ('sales', 'NNS'),
#   ('management', 'NN'),
#   ('experience', 'NN'),
#   ('include', 'VB'),
#   ('at', 'IN'),
#   ('least', 'AP'),
#   ('2', 'CD'),
#   ('successful', 'JJ'),
#   ('hires', 'VBZ'),
#   ('of', 'IN'),
#   ('outside', 'JJ'),
#   ('sales', 'NNS'),
#   ('people', 'NNS'),
#   ('working', 'VBG'),
#   ('in', 'IN'),
#   ('remote', 'JJ'),
#   ('locations', 'NNS'),
#   (',', ','),
#   ('within', 'IN'),
#   ('the', 'AT'),
#   ('past', 'NN'),
#   ('2', 'CD'),
#   ('years', 'NNS'),
#   ('?', '.')],
#  [('How', 'WRB'),
#   ('do', 'DO'),
#   ('you', 'PPSS'),
#   ('define', 'VB'),
#   ('a', 'AT'),
#   ('successful', 'JJ'),
#   ('hire', 'VB'),
#   ('?', '.')],
#  [('How', 'WRB'),
#   ('long', 'JJ'),
#   ('did', 'DOD'),
#   ('it', 'PPO'),
#   ('take', 'VB'),
#   ('to', 'TO'),
#   ('determine', 'VB'),
#   ('who', 'WPS'),
#   ('are', 'BER'),
#   ('the', 'AT'),
#   ('``', '``'),
#   ('A', 'AT'),
#   ("''", "''"),
#   (',', ','),
#   ('``', '``'),
#   ('B', 'NN'),
#   ("''", "''"),
#   ('and', 'CC'),
#   ('others', 'NNS'),
#   ('on', 'IN'),
#   ('your', 'PP$'),
#   ('sales', 'NNS'),
#   ('staff', 'NN'),
#   ('?', '.')],
#  [('What', 'WDT'),
#   ('is', 'BEZ'),
#   ('your', 'PP$'),
#   ('strategy', 'NN'),
#   ('for', 'IN'),
#   ('improving', 'VBG'),
#   ('your', 'PP$'),
#   ('entire', 'JJ'),
#   ('sales', 'NNS'),
#   ('staff', 'NN'),
#   ('-', 'IN'),
#   ('direct', 'JJ'),
#   ('and', 'CC'),
#   ('indirect', 'JJ'),
#   ('?', '.')],
#  [('Do', 'DO'),
#   ('you', 'PPSS'),
#   ('believe', 'VB'),
#   ('that', 'CS'),
#   ('effective', 'JJ'),
#   ('development', 'NN'),
#   ('and', 'CC'),
#   ('utilization', 'NN'),
#   ('of', 'IN'),
#   ('your', 'PP$'),
#   ('staff', 'NN'),
#   ('is', 'BEZ'),
#   ('fundamental', 'JJ'),
#   ('to', 'TO'),
#   ('advancing', 'VBG'),
#   ('your', 'PP$'),
#   ('own', 'JJ'),
#   ('career', 'NN'),
#   ('?', '.')],
#  [('Does', 'DOZ'),
#   ('your', 'PP$'),
#   ('sales', 'NNS'),
#   ('management', 'NN'),
#   ('experience', 'NN'),
#   ('include', 'VB'),
#   ('responsibility', 'NN'),
#   ('for', 'IN'),
#   ('multiple', 'JJ'),
#   ('distributor', 'NN'),
#   ('partners', 'NNS'),
#   ('?', '.')],
#  [('How', 'WRB'),
#   ('long', 'JJ'),
#   ('did', 'DOD'),
#   ('it', 'PPO'),
#   ('take', 'VB'),
#   ('to', 'TO'),
#   ('determine', 'VB'),
#   ('who', 'WPS'),
#   ('your', 'PP$'),
#   ('high', 'JJ'),
#   ('performing', 'VBG'),
#   ('distributor', 'NN'),
#   ('partners', 'NNS'),
#   ('are', 'BER'),
#   ('?', '.')],
#  [('Have', 'HV'),
#   ('you', 'PPSS'),
#   ('participated', 'VBN'),
#   ('in', 'IN'),
#   ('quarterly', 'JJ'),
#   ('reviews', 'NNS'),
#   ('with', 'IN'),
#   ('key', 'JJS'),
#   ('distributors', 'NNS'),
#   ('?', '.')],
#  [('Do', 'DO'),
#   ('your', 'PP$'),
#   ('accomplishments', 'NNS'),
#   ('include', 'VB'),
#   ('identifying', 'VBG'),
#   ('and', 'CC'),
#   ('attracting', 'VBG'),
#   ('new', 'JJ'),
#   ('high-performing', 'NN'),
#   ('distributor', 'NN'),
#   ('partners', 'NNS'),
#   ('?', '.')],
#  [('Are', 'BER'),
#   ('you', 'PPSS'),
#   ('looking', 'VBG'),
#   ('for', 'IN'),
#   ('a', 'AT'),
#   ('successful', 'JJ'),
#   ('international', 'JJ'),
#   ('organization', 'NN'),
#   ('with', 'IN'),
#   ('recognized', 'VBN'),
#   ('brands', 'NNS'),
#   (',', ','),
#   ('a', 'AT'),
#   ('reputation', 'NN'),
#   ('for', 'IN'),
#   ('quality', 'NN'),
#   ('products', 'NNS'),
#   ('and', 'CC'),
#   ('solutions', 'NNS'),
#   ('plus', 'CC'),
#   ('high', 'JJ'),
#   ('ethical', 'JJ'),
#   ('standards', 'NNS'),
#   ('?', '.')],
#  [('Do', 'DO'),
#   ('you', 'PPSS'),
#   ('enjoy', 'VB'),
#   ('consultative', 'JJ'),
#   ('sales', 'NNS'),
#   ('that', 'WPS'),
#   ('challenge', 'VB'),
#   ('you', 'PPO'),
#   ('and', 'CC'),
#   ('your', 'PP$'),
#   ('staff', 'NN'),
#   ('to', 'IN'),
#   ('learn', 'VB'),
#   ('a', 'AT'),
#   ('wide', 'JJ'),
#   ('range', 'NN'),
#   ('of', 'IN'),
#   ('applications', 'NNS'),
#   ('and', 'CC'),
#   ('make', 'VB'),
#   ('thoughtful', 'JJ'),
#   ('recommendations', 'NNS'),
#   ('?', '.')],
#  [('If', 'CS'),
#   ('you', 'PPSS'),
#   ('are', 'BER'),
#   ('looking', 'VBG'),
#   ('for', 'IN'),
#   ('a', 'AT'),
#   ('sales', 'NNS'),
#   ('leadership', 'NN'),
#   ('opportunity', 'NN'),
#   ('that', 'CS'),
#   ('provides', 'VBZ'),
#   ('high', 'JJ'),
#   ('visibility', 'NN'),
#   (',', ','),
#   ('recognition', 'NN'),
#   ('and', 'CC'),
#   ('rewards', 'NNS'),
#   ('for', 'IN'),
#   ('your', 'PP$'),
#   ('accomplishments', 'NNS'),
#   ('plus', 'CC'),
#   ('selling', 'VBG'),
#   ('products', 'NNS'),
#   ('that', 'WPS'),
#   ('protect', 'VB'),
#   ('lives', 'NNS'),
#   ('and', 'CC'),
#   ('property', 'NN'),
#   ('-', 'IN'),
#   ('necessary', 'JJ'),
#   ('products', 'NNS'),
#   ('-', 'IN'),
#   ('then', 'RB'),
#   ('keep', 'VB'),
#   ('reading', 'VBG'),
#   ('.', '.')],
#  [('Accountabilities', 'NN'), ('&', 'CC'), ('amp', 'NN')],
#  [('responsibilities', 'NNS')],
#  [('The', 'AT'),
#   ('Divisional', 'NN'),
#   ('Sales', 'NNS'),
#   ('Director', 'NN-TL'),
#   (',', ','),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('reports', 'NNS'),
#   ('directly', 'RB'),
#   ('to', 'IN'),
#   ('the', 'AT'),
#   ('VP', 'NN'),
#   ('of', 'IN'),
#   ('Sales', 'NNS'),
#   ('and', 'CC'),
#   ('is', 'BEZ'),
#   ('primarily', 'RB'),
#   ('responsible', 'JJ'),
#   ('for', 'IN'),
#   ('approximately', 'RB'),
#   ('$', 'NN'),
#   ('20M', 'NN'),
#   ('in', 'IN'),
#   ('revenue', 'NN'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('Divisional', 'NN'),
#   ('Sales', 'NNS'),
#   ('Director', 'NN-TL'),
#   (',', ','),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('keeps', 'VBZ'),
#   ('the', 'AT'),
#   ('VP', 'NN'),
#   ('of', 'IN'),
#   ('Sales', 'NNS'),
#   ('informed', 'VBN'),
#   ('about', 'IN'),
#   ('sales', 'NNS'),
#   ('initiatives', 'NN'),
#   ('for', 'IN'),
#   ('and', 'CC'),
#   ('by', 'IN'),
#   ('the', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   (':', ':'),
#   ('orders', 'NNS'),
#   ('recently', 'RB'),
#   ('closed', 'VBN'),
#   (',', ','),
#   ('orders', 'NNS'),
#   ('pending', 'JJ'),
#   (',', ','),
#   ('staff', 'NN'),
#   ('performance', 'NN'),
#   ('and', 'CC'),
#   ('development', 'NN'),
#   (',', ','),
#   ('distributors', 'NNS'),
#   ("'", "'"),
#   ('performance', 'NN'),
#   ('and', 'CC'),
#   ('development', 'NN'),
#   ('plus', 'CC'),
#   ('competitive', 'JJ'),
#   ('activities', 'NNS'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('essence', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('Divisional', 'NN'),
#   ('Sales', 'NNS'),
#   ('Director', 'NN-TL'),
#   (',', ','),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('position', 'NN'),
#   ('is', 'BEZ'),
#   ('leadership', 'NN'),
#   (':', ':'),
#   ('strategic', 'JJ'),
#   (',', ','),
#   ('tactical', 'JJ'),
#   (',', ','),
#   ('staff', 'NN'),
#   ('and', 'CC'),
#   ('distributor', 'NN'),
#   ('leadership', 'NN'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('successful', 'JJ'),
#   ('Divisional', 'NN'),
#   ('Sales', 'NNS'),
#   ('Director', 'NN-TL'),
#   ('acts', 'VBZ'),
#   ('proactively', 'NN'),
#   (',', ','),
#   ('is', 'BEZ'),
#   ('a', 'AT'),
#   ('team-player', 'NN'),
#   ('and', 'CC'),
#   ('team-leader', 'NN'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('is', 'BEZ'),
#   ('expected', 'VBN'),
#   ('to', 'TO'),
#   ('grow', 'VB'),
#   ('significantly', 'RB'),
#   ('in', 'IN'),
#   ('terms', 'NNS'),
#   ('of', 'IN'),
#   ('sales', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('coming', 'VBG'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('Leadership', 'NN')],
#  [('The', 'AT'),
#   ('Divisional', 'NN'),
#   ('Sales', 'NNS'),
#   ('Director', 'NN-TL'),
#   (',', ','),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('must', 'MD'),
#   ('lead', 'VB'),
#   ('by', 'IN'),
#   ('example:', 'NN')],
#  [('Model', 'NN-TL'),
#   ('the', 'AT'),
#   ('qualities', 'NNS'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('sales', 'NNS'),
#   ('hunter', 'NN')],
#  [('consistently', 'RB'),
#   ('searching', 'VBG'),
#   ('for', 'IN'),
#   ('new', 'JJ'),
#   ('opportunities', 'NNS'),
#   ('and', 'CC'),
#   ('relationships', 'NNS'),
#   ('across', 'IN'),
#   ('targeted', 'NN'),
#   ('industries', 'NNS'),
#   (',', ','),
#   ('not', '*'),
#   ('just', 'RB'),
#   ('the', 'AT'),
#   ('industries', 'NNS'),
#   ('that', 'WPS'),
#   ('the', 'AT'),
#   ('sales', 'NNS'),
#   ('people', 'NNS'),
#   ('are', 'BER'),
#   ('comfortable', 'JJ'),
#   ('with', 'IN'),
#   ('or', 'CC'),
#   ('where', 'WRB'),
#   ('they', 'PPSS'),
#   ('have', 'HV'),
#   ('contacts', 'NNS'),
#   ('.', '.')],
#  [('Model', 'NN-TL'),
#   ('the', 'AT'),
#   ('qualities', 'NNS'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('sales', 'NNS'),
#   ('professional', 'JJ')],
#  [('think', 'VB'),
#   ('proactively', 'NN'),
#   ('and', 'CC'),
#   ('strategically', 'RB'),
#   (',', ','),
#   ('develop', 'VB'),
#   ('sales', 'NNS'),
#   ('tactics', 'NNS'),
#   ('for', 'IN'),
#   ('themselves', 'PPLS'),
#   ('and', 'CC'),
#   ('the', 'AT'),
#   ('sales', 'NNS'),
#   ('people', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('that', 'CS'),
#   ('cultivate', 'VB'),
#   ('strong', 'JJ'),
#   ('professional', 'JJ'),
#   ('relationships', 'NNS'),
#   (',', ','),
#   ('reinforcing', 'VBG'),
#   ('the', 'AT'),
#   ('Company', 'NN-TL'),
#   ("'s", 'NN'),
#   ('commitment', 'NN'),
#   ('to', 'IN'),
#   ('the', 'AT'),
#   ('highest', 'JJT'),
#   ('ethical', 'JJ'),
#   ('standards', 'NNS'),
#   ('AND', 'NN'),
#   ('result', 'NN'),
#   ('in', 'IN'),
#   ('sales', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('current', 'JJ'),
#   ('fiscal', 'JJ'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('Demonstrate', 'VB'),
#   ('the', 'AT'),
#   ('effective', 'JJ'),
#   ('utilization', 'NN'),
#   ('of', 'IN'),
#   ('sales', 'NNS'),
#   ('tools', 'NNS'),
#   ('and', 'CC'),
#   ('resources', 'NNS'),
#   ('that', 'WPS'),
#   ('create', 'VB'),
#   ('strong', 'JJ'),
#   ('positive', 'JJ'),
#   ('impressions', 'NNS'),
#   ('with', 'IN'),
#   ('prospective', 'JJ'),
#   ('customers', 'NNS'),
#   (',', ','),
#   ('distribution', 'NN'),
#   ('partners', 'NNS'),
#   ('and', 'CC'),
#   ('Company', 'NN-TL'),
#   ('personnel', 'NNS'),
#   ('.', '.')],
#  [('Management', 'NN-TL')],
#  [('The', 'AT'),
#   ('Divisional', 'NN'),
#   ('Sales', 'NNS'),
#   ('Director', 'NN-TL'),
#   (',', ','),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('is', 'BEZ'),
#   ('responsible', 'JJ'),
#   ('for', 'IN'),
#   ('7', 'CD'),
#   ('direct', 'JJ'),
#   ('reports', 'NNS'),
#   ('.', '.')],
#  [('In', 'IN'), ('your', 'PP$'), ('management', 'NN'), ('capacity:', 'NN')],
#  [('Set', 'VB'),
#   ('and', 'CC'),
#   ('clearly', 'RB'),
#   ('communicate', 'VB'),
#   ('performance', 'NN'),
#   ('expectations', 'NNS'),
#   ('.', '.')],
#  [('Consistently', 'NN'),
#   ('track/monitor', 'NN'),
#   ('each', 'DT'),
#   ('individual', 'NN'),
#   ("'s", 'NN'),
#   ('performance', 'NN'),
#   ('against', 'IN'),
#   ('expectations', 'NNS'),
#   ('.', '.')],
#  [('Based', 'VBN'),
#   ('on', 'IN'),
#   ('conversations', 'NNS'),
#   (',', ','),
#   ('direct', 'JJ'),
#   ('observations', 'NNS'),
#   ('of', 'IN'),
#   ('performance', 'NN'),
#   (',', ','),
#   ('sales', 'NNS'),
#   ('call', 'VB'),
#   ('planning', 'VBG'),
#   (',', ','),
#   ('utilization', 'NN'),
#   ('of', 'IN'),
#   ('company', 'NN'),
#   ('resources', 'NNS'),
#   (',', ','),
#   ('time', 'NN'),
#   ('and', 'CC'),
#   ('territory', 'NN'),
#   ('management', 'NN'),
#   (',', ','),
#   ('identify', 'VB'),
#   ('strengths', 'NNS'),
#   ('and', 'CC'),
#   ('areas', 'NNS'),
#   ('for', 'IN'),
#   ('improvement', 'NN'),
#   ('for', 'IN'),
#   ('each', 'DT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('.', '.')],
#  [('On', 'IN'),
#   ('a', 'AT'),
#   ('monthly', 'JJ'),
#   ('basis', 'NN'),
#   (',', ','),
#   ('review', 'NN'),
#   ('the', 'AT'),
#   ('performance', 'NN'),
#   ('of', 'IN'),
#   ('each', 'DT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('VP', 'NN'),
#   ('of', 'IN'),
#   ('Sales', 'NNS'),
#   ('.', '.')],
#  [('During', 'IN'),
#   ('these', 'DTS'),
#   ('performance', 'NN'),
#   ('reviews', 'VBZ'),
#   (',', ','),
#   ('summarize', 'VB'),
#   ('actions', 'NNS'),
#   ('taken', 'VBN'),
#   ('to', 'TO'),
#   ('elevate', 'NN'),
#   ('each', 'DT'),
#   ('members', 'NNS'),
#   ("'", "'"),
#   ('performance', 'NN'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('appropriate', 'JJ'),
#   (',', ','),
#   ('make', 'VB'),
#   ('recommendations', 'NNS'),
#   ('to', 'TO'),
#   ('and', 'CC'),
#   ('solicit', 'VB'),
#   ('input', 'NN'),
#   ('from', 'IN'),
#   ('the', 'AT'),
#   ('VP', 'NN'),
#   ('of', 'IN'),
#   ('Sales', 'NNS'),
#   ('to', 'TO'),
#   ('raise', 'VB'),
#   ('performance', 'NN'),
#   ('of', 'IN'),
#   ('each', 'DT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('.', '.')],
#  [('On', 'IN'),
#   ('a', 'AT'),
#   ('monthly', 'JJ'),
#   ('basis', 'NN'),
#   (',', ','),
#   ('review', 'NN'),
#   ('the', 'AT'),
#   ('performance', 'NN'),
#   ('of', 'IN'),
#   ('each', 'DT'),
#   ('distributor', 'NN'),
#   ('partner', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('VP', 'NN'),
#   ('of', 'IN'),
#   ('Sales', 'NNS'),
#   ('.', '.')],
#  [('During', 'IN'),
#   ('these', 'DTS'),
#   ('performance', 'NN'),
#   ('reviews', 'VBZ'),
#   (',', ','),
#   ('summarize', 'VB'),
#   ('actions', 'NNS'),
#   ('taken', 'VBN'),
#   ('to', 'TO'),
#   ('elevate', 'NN'),
#   ('each', 'DT'),
#   ('distributors', 'NNS'),
#   ('performance', 'NN'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('appropriate', 'JJ'),
#   (',', ','),
#   ('make', 'VB'),
#   ('recommendations', 'NNS'),
#   ('to', 'TO'),
#   ('and', 'CC'),
#   ('solicit', 'VB'),
#   ('input', 'NN'),
#   ('from', 'IN'),
#   ('the', 'AT'),
#   ('VP', 'NN'),
#   ('of', 'IN'),
#   ('Sales', 'NNS'),
#   ('to', 'TO'),
#   ('raise', 'VB'),
#   ('performance', 'NN'),
#   ('of', 'IN'),
#   ('each', 'DT'),
#   ('distributor', 'NN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('.', '.')],
#  [('Value', 'NN'), ('selling', 'VBG')],
#  [('This', 'DT'),
#   ('is', 'BEZ'),
#   ('not', '*'),
#   ('a', 'AT'),
#   ('commodity', 'NN'),
#   ('business', 'NN'),
#   ('-', 'IN'),
#   ('this', 'DT'),
#   ('Company', 'NN-TL'),
#   ('does', 'DOZ'),
#   ('not', '*'),
#   ('sell', 'VB'),
#   ('on', 'IN'),
#   ('price', 'NN'),
#   ('!', '.')],
#  [('It', 'PPS'),
#   ('is', 'BEZ'),
#   ('imperative', 'JJ'),
#   ('that', 'CS'),
#   ('all', 'ABN'),
#   ('sales', 'NNS'),
#   ('personnel', 'NNS'),
#   ('be', 'BE'),
#   ('trained', 'VBN'),
#   ('in', 'IN'),
#   ('and', 'CC'),
#   ('practice', 'NN'),
#   ('daily', 'RB'),
#   ('value', 'NN'),
#   ('selling', 'VBG'),
#   ('principles', 'NNS'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('Company', 'NN-TL'),
#   ('delivers', 'VBZ'),
#   ('products', 'NNS'),
#   ('and', 'CC'),
#   ('services', 'NNS'),
#   ('that', 'WPS'),
#   ('are', 'BER'),
#   ('solutions', 'NNS'),
#   ('to', 'TO'),
#   ('customers', 'NNS'),
#   ("'", "'"),
#   ('needs', 'NNS'),
#   ('and', 'CC'),
#   ('business', 'NN'),
#   ('issues', 'NNS'),
#   ('.', '.')],
#  [('It', 'PPS'),
#   ('is', 'BEZ'),
#   ('imperative', 'JJ'),
#   ('that', 'CS'),
#   ('every', 'AT'),
#   ('member', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('have', 'HV'),
#   ('``', '``'),
#   ('expert', 'NN'),
#   ("''", "''"),
#   ('knowledge', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('Company', 'NN-TL'),
#   ("'s", 'NN'),
#   ('products', 'NNS'),
#   ('and', 'CC'),
#   ('services', 'NNS'),
#   ('and', 'CC'),
#   ('be', 'BE'),
#   ('effective', 'JJ'),
#   ('articulating', 'NN'),
#   ('the', 'AT'),
#   ('unique', 'JJ'),
#   ('value', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('Company', 'NN-TL'),
#   ("'s", 'NN'),
#   ('products', 'NNS'),
#   ('and', 'CC'),
#   ('services', 'NNS'),
#   ('versus', 'IN'),
#   ('competitive', 'JJ'),
#   ('products', 'NNS'),
#   ('.', '.')],
#  [('Maintain', 'VB'),
#   ('current', 'JJ'),
#   ('knowledge', 'NN'),
#   ('of', 'IN'),
#   ('Federal', 'JJ-TL'),
#   (',', ','),
#   ('State', 'NN-TL'),
#   (',', ','),
#   ('Provincial', 'JJ-TL'),
#   ('and', 'CC'),
#   ('Local', 'JJ'),
#   ('safety', 'NN'),
#   ('regulations', 'NNS'),
#   ('pertaining', 'VBG'),
#   ('to', 'TO'),
#   ('the', 'AT'),
#   ('Company', 'NN-TL'),
#   ("'s", 'NN'),
#   ('products', 'NNS'),
#   ('and', 'CC'),
#   ('solutions', 'NNS'),
#   ('-', 'IN'),
#   ('educate', 'VB'),
#   ('sales', 'NNS'),
#   ('staff', 'NN'),
#   ('and', 'CC'),
#   ('if/when', 'NN'),
#   ('appropriate', 'JJ'),
#   ('distributors', 'NNS'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('utilize', 'VB'),
#   ('this', 'DT'),
#   ('information', 'NN'),
#   ('to', 'IN'),
#   ('prospect', 'NN'),
#   ('for', 'IN'),
#   ('and', 'CC'),
#   ('close', 'VB'),
#   ('business', 'NN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('current', 'JJ'),
#   ('fiscal', 'JJ'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('Distributor', 'NN'), ('management', 'NN'), ('responsibilities', 'NNS')],
#  [('Work', 'NN'),
#   ('with', 'IN'),
#   ('sales', 'NNS'),
#   ('staff', 'NN'),
#   ('to', 'IN'),
#   ('strengthen', 'VB'),
#   ('overall', 'JJ'),
#   ('distributor', 'NN'),
#   ('portfolio', 'NN'),
#   ('.', '.')],
#  [('Develop', 'VB'),
#   ('and', 'CC'),
#   ('coach', 'NN'),
#   ('distributor', 'NN'),
#   ('partners', 'NNS'),
#   ('to', 'TO'),
#   ('higher', 'JJR'),
#   ('levels', 'NNS'),
#   ('of', 'IN'),
#   ('performance', 'NN'),
#   (',', ','),
#   ('coach', 'NN'),
#   ('and', 'CC'),
#   ('eliminate', 'VB'),
#   ('weak', 'JJ'),
#   ('distributor', 'NN'),
#   ('partners', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('identify', 'VB'),
#   ('and', 'CC'),
#   ('attract', 'VB'),
#   ('new', 'JJ'),
#   ('high-performing', 'NN'),
#   ('distributor', 'NN'),
#   ('partners', 'NNS'),
#   ('.', '.')],
#  [('Participate', 'VB'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('RSM', 'NN'),
#   ("'s", 'NN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('annual', 'JJ'),
#   ('planning', 'NN'),
#   ('process', 'NN'),
#   ('and', 'CC'),
#   ('quarterly', 'JJ'),
#   ('reviews', 'NNS'),
#   ('with', 'IN'),
#   ('key', 'JJS'),
#   ('distributors', 'NNS'),
#   ('.', '.')],
#  [('Review', 'VB'),
#   ('and', 'CC'),
#   ('approve', 'VB'),
#   ('any', 'DTI'),
#   ('changes', 'NNS'),
#   ('to', 'TO'),
#   ('distributor', 'NN'),
#   ('partners', 'NNS'),
#   ('recommended', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'AT'),
#   ('RSM', 'NN'),
#   ("'s", 'NN'),
#   ('.', '.')],
#  [('Manage', 'VB'),
#   ('and', 'CC'),
#   ('approve', 'VB'),
#   ('any', 'DTI'),
#   ('price', 'NN'),
#   ('exceptions', 'NNS'),
#   ('within', 'IN'),
#   ('guidelines', 'NNS'),
#   ('.', '.')],
#  [('Cross', 'NN-TL'), ('functional', 'JJ'), ('accountabilities', 'NN')],
#  [('Develop', 'VB'),
#   ('and', 'CC'),
#   ('maintain', 'VB'),
#   ('strong', 'JJ'),
#   ('working', 'VBG'),
#   ('relationships', 'NNS'),
#   ('with', 'IN'),
#   ('peers', 'NNS'),
#   ('and', 'CC'),
#   ('colleagues', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('Sales', 'NNS'),
#   ('organization', 'NN'),
#   (',', ','),
#   ('plus', 'CC'),
#   ('Marketing', 'VBG-TL'),
#   (',', ','),
#   ('Finance', 'NN-TL'),
#   (',', ','),
#   ('and', 'CC'),
#   ('Operations', 'NNS-TL'),
#   ('functions', 'NNS'),
#   ('-', 'IN'),
#   ('this', 'DT'),
#   ('is', 'BEZ'),
#   ('Critical', 'JJ'),
#   ('.', '.')],
#  [('Embrace', 'NN'),
#   ('and', 'CC'),
#   ('promote', 'VB'),
#   ('a', 'AT'),
#   ('collaborative', 'NN'),
#   ('working', 'VBG'),
#   ('environment', 'NN'),
#   ('with', 'IN'),
#   ('all', 'ABN'),
#   ('Company', 'NN-TL'),
#   ('employees', 'NNS'),
#   ('.', '.')],
#  [('Sales', 'NNS'), ('administration', 'NN'), ('responsibilities', 'NNS')],
#  [('Make', 'VB'),
#   ('sure', 'JJ'),
#   ('all', 'ABN'),
#   ('personnel', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('are', 'BER'),
#   ('proficient', 'JJ'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('effective', 'JJ'),
#   ('utilization', 'NN'),
#   ('of', 'IN'),
#   ('all', 'ABN'),
#   ('tools', 'NNS'),
#   ('provided', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'AT'),
#   ('Company', 'NN-TL'),
#   ('such', 'JJ'),
#   ('as', 'CS'),
#   (':', ':'),
#   ('CRM', 'NN'),
#   ('system', 'NN'),
#   (',', ','),
#   ('email', 'NN'),
#   (',', ','),
#   ('word', 'NN'),
#   ('processing', 'NN'),
#   (',', ','),
#   ('sales', 'NNS'),
#   ('reports', 'NNS'),
#   (',', ','),
#   ('presentation', 'NN'),
#   ('and', 'CC'),
#   ('spreadsheet', 'NN'),
#   ('software', 'NN'),
#   (',', ','),
#   ('etc', 'NN'),
#   ('.', '.')],
#  [('Monitor', 'VB'),
#   ('expenses', 'NNS'),
#   ('for', 'IN'),
#   ('compliance', 'NN'),
#   ('with', 'IN'),
#   ('policies', 'NNS'),
#   (',', ','),
#   ('appropriate', 'JJ'),
#   ('business', 'NN'),
#   ('expenses', 'NNS'),
#   ('and', 'CC'),
#   ('justified', 'VBN'),
#   ('within', 'IN'),
#   ('budget', 'NN'),
#   ('guidelines', 'NNS'),
#   ('.', '.')],
#  [('Maintain', 'VB'),
#   ('accurate', 'JJ'),
#   ('records', 'NNS'),
#   ('regarding', 'IN'),
#   ('the', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Division', 'NN-TL'),
#   ("'s", 'NN'),
#   ('consignment', 'NN'),
#   ('and', 'CC'),
#   ('demo', 'NN'),
#   ('equipment', 'NN')],
#  [('is', 'BEZ'),
#   ('it', 'PPS'),
#   ('in', 'IN'),
#   ('good', 'JJ'),
#   ('condition', 'NN'),
#   (',', ','),
#   ('appropriately', 'RB'),
#   ('maintained', 'VBN'),
#   (',', ','),
#   ('utilized/demonstrated', 'NN'),
#   ('appropriately', 'RB'),
#   ('.', '.')],
#  [('Make', 'VB'),
#   ('sure', 'JJ'),
#   ('all', 'ABN'),
#   ('personnel', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('are', 'BER'),
#   ('maintaining', 'VBG'),
#   ('and', 'CC'),
#   ('utilizing', 'VBG'),
#   ('Company', 'NN-TL'),
#   ("'s", 'NN'),
#   ('property', 'NN'),
#   ('appropriately', 'RB'),
#   ('and', 'CC'),
#   ('in', 'IN'),
#   ('good', 'JJ'),
#   ('working', 'VBG'),
#   ('condition', 'NN'),
#   ('.', '.')],
#  [('Personal', 'JJ'), ('selling', 'VBG'), ('responsibilities', 'NNS')],
#  [('Identify', 'NN'),
#   ('decision', 'NN'),
#   ('makers', 'NNS'),
#   ('and', 'CC'),
#   ('decision', 'NN'),
#   ('influencers', 'NN'),
#   ('within', 'IN'),
#   ('each', 'DT'),
#   ('targeted', 'NN'),
#   ('industry', 'NN'),
#   ('.', '.')],
#  [('Develop', 'VB'),
#   ('strong', 'JJ'),
#   ('professional', 'JJ'),
#   ('relationships', 'NNS'),
#   ('with', 'IN'),
#   ('decision', 'NN'),
#   ('makers', 'NNS'),
#   ('and', 'CC'),
#   ('decision', 'NN'),
#   ('influencers', 'NN'),
#   ('within', 'IN'),
#   ('each', 'DT'),
#   ('targeted', 'NN'),
#   ('industry', 'NN'),
#   ('.', '.')],
#  [('Develop', 'VB'),
#   ('strong', 'JJ'),
#   ('professional', 'JJ'),
#   ('relationships', 'NNS'),
#   ('with', 'IN'),
#   ('key', 'JJS'),
#   ('management', 'NN'),
#   ('with', 'IN'),
#   ('the', 'AT'),
#   ('Company', 'NN-TL'),
#   ("'s", 'NN'),
#   ('premier', 'NN'),
#   ('distributors', 'NNS'),
#   ('.', '.')],
#  [('Develop', 'VB'),
#   ('strong', 'JJ'),
#   ('professional', 'JJ'),
#   ('relationships', 'NNS'),
#   ('with', 'IN'),
#   ('current', 'JJ'),
#   ('and', 'CC'),
#   ('potential', 'JJ'),
#   ('large', 'JJ'),
#   ('channel', 'NN'),
#   ('partners', 'NNS'),
#   ('.', '.')],
#  [('Develop', 'VB'),
#   ('strong', 'JJ'),
#   ('professional', 'JJ'),
#   ('relationships', 'NNS'),
#   ('with', 'IN'),
#   ('all', 'ABN'),
#   ('distribution', 'NN'),
#   ('partners', 'NNS'),
#   ('that', 'WPS'),
#   ('interact', 'VB'),
#   ('with', 'IN'),
#   ('and', 'CC'),
#   ('support', 'VB'),
#   ('the', 'AT'),
#   ('Western', 'JJ-TL'),
#   ('Region', 'NN-TL'),
#   ('.', '.')],
#  [('Company', 'NN')],
#  [('Our', 'PP$'),
#   ('client', 'NN'),
#   ('is', 'BEZ'),
#   ('a', 'AT'),
#   ('global', 'JJ'),
#   ('manufacturer', 'NN'),
#   ('of', 'IN'),
#   ('sophisticated', 'JJ'),
#   ('and', 'CC'),
#   ('innovative', 'NN'),
#   ('technologies', 'NN'),
#   ('and', 'CC'),
#   ('solutions', 'NNS'),
#   ('to', 'TO'),
#   ('protect', 'VB'),
#   ('support', 'NN'),
#   ('and', 'CC'),
#   ('save', 'VB'),
#   ('workers', 'NNS'),
#   ('who', 'WPS'),
#   ('may', 'MD'),
#   ('be', 'BE'),
#   ('exposed', 'VBN'),
#   ('to', 'TO'),
#   ('a', 'AT'),
#   ('variety', 'NN'),
#   ('of', 'IN'),
#   ('hazardous', 'JJ'),
#   ('conditions', 'NNS'),
#   ('.', '.')],
#  [('Compensation', 'NN')],
#  [('The', 'AT'),
#   ('compensation', 'NN'),
#   ('package', 'NN'),
#   ('consists', 'VBZ'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('salary', 'NN'),
#   ('based', 'VBN'),
#   ('on', 'IN'),
#   ('experience', 'NN'),
#   (',', ','),
#   ('incentive', 'NN'),
#   ('compensation', 'NN'),
#   ('-', 'IN'),
#   ('which', 'WDT'),
#   ('is', 'BEZ'),
#   ('paid', 'VBN'),
#   ('monthly', 'JJ'),
#   ('-', 'IN'),
#   ('plus', 'CC'),
#   ('a', 'AT'),
#   ('highly', 'QL'),
#   ('competitive', 'JJ'),
#   ('and', 'CC'),
#   ('comprehensive', 'JJ'),
#   ('benefits', 'NNS'),
#   ('package', 'NN'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('Company', 'NN-TL'),
#   ('believes', 'VBZ'),
#   ('that', 'CS'),
#   ('in', 'IN'),
#   ('addition', 'NN'),
#   ('to', 'IN'),
#   ('recognition', 'NN'),
#   (',', ','),
#   ('productive', 'JJ'),
#   ('and', 'CC'),
#   ('effective', 'JJ'),
#   ('employees', 'NNS'),
#   ('enjoy', 'VB'),
#   ('a', 'AT'),
#   ('healthy', 'JJ'),
#   ('work-life', 'NN'),
#   ('balance', 'NN'),
#   ('.', '.')],
#  [('If', 'CS'),
#   ('you', 'PPSS'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('sell', 'VB'),
#   ('products', 'NNS'),
#   ('that', 'WPS'),
#   ('can', 'MD'),
#   ('have', 'HV'),
#   ('a', 'AT'),
#   ('meaningful', 'JJ'),
#   ('impact', 'NN'),
#   ('on', 'IN'),
#   ('peoples', 'NNS'),
#   ("'", "'"),
#   ('lives', 'NNS'),
#   (',', ','),
#   ('if', 'CS'),
#   ('you', 'PPSS'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('represent', 'VB'),
#   ('a', 'AT'),
#   ('company', 'NN'),
#   ('committed', 'VBN'),
#   ('to', 'TO'),
#   ('developing', 'VBG'),
#   ('innovative', 'NN'),
#   ('products', 'NNS'),
#   (',', ','),
#   ('if', 'CS'),
#   ('you', 'PPSS'),
#   ('are', 'BER'),
#   ('looking', 'VBG'),
#   ('for', 'IN'),
#   ('a', 'AT'),
#   ('company', 'NN'),
#   ('that', 'CS'),
#   ('will', 'MD'),
#   ('acknowledge', 'VB'),
#   ('and', 'CC'),
#   ('reward', 'NN'),
#   ('accomplishments', 'NNS'),
#   (',', ','),
#   ('you', 'PPSS'),
#   ('might', 'MD'),
#   ('have', 'HV'),
#   ('a', 'AT'),
#   ('home', 'NN'),
#   ('here', 'RB'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('timeframe', 'NN'),
#   ('to', 'IN'),
#   ('fill', 'VB'),
#   ('this', 'DT'),
#   ('search', 'NN'),
#   ('is', 'BEZ'),
#   ('as-soon-as-possible', 'NN'),
#   ('.', '.')],
#  [('Field', 'NN-TL'),
#   ('Training', 'NN-TL'),
#   ('Specialist', 'NN-TL'),
#   (',', ','),
#   ('L', 'NP'),
#   ('&', 'CC-TL'),
#   ('D', 'NP')],
#  [('Position', 'NN'), ('Summary:', 'NN')],
#  [('Reporting', 'NN'),
#   ('to', 'IN'),
#   ('the', 'AT'),
#   ('Director', 'NN-TL'),
#   ('of', 'IN-TL'),
#   ('Training', 'VBG-TL'),
#   ('as', 'CS'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('dynamic', 'JJ'),
#   ('Learning', 'NN'),
#   ('and', 'CC'),
#   ('Development', 'NN-TL'),
#   ('team', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('Learning', 'NN'),
#   ('and', 'CC'),
#   ('Development', 'NN-TL'),
#   ('Field', 'NN-TL'),
#   ('Training', 'NN-TL'),
#   ('Specialist', 'NN-TL'),
#   ('is', 'BEZ'),
#   ('responsible', 'JJ'),
#   ('for', 'IN'),
#   ('developing', 'VBG'),
#   ('and', 'CC'),
#   ('facilitating', 'VBG'),
#   ('training', 'NN'),
#   ('and', 'CC'),
#   ('development', 'NN'),
#   ('programs', 'NNS'),
#   ('to', 'TO'),
#   ('support', 'VB'),
#   ('identifying', 'VBG'),
#   (',', ','),
#   ('engaging', 'JJ'),
#   (',', ','),
#   ('developing', 'VBG'),
#   ('MarketSource', 'NN'),
#   ('field', 'NN'),
#   ('populations', 'NNS'),
#   ('.', '.')],
#  [('Primary', 'JJ'),
#   ('responsibilities', 'NNS'),
#   ('include', 'VB'),
#   ('facilitating', 'VBG'),
#   ('and', 'CC'),
#   ('identifying', 'VBG'),
#   ('core', 'NN'),
#   ('training', 'NN'),
#   ('needs', 'VBZ'),
#   ('throughout', 'IN'),
#   ('the', 'AT'),
#   ('employee', 'NN'),
#   ('lifecycle', 'NN'),
#   ('to', 'IN'),
#   ('include', 'VB'),
#   ('performance-related', 'NN'),
#   ('trainings', 'NN'),
#   ('such', 'JJ'),
#   ('as', 'CS'),
#   ('sales', 'NNS'),
#   ('training', 'NN'),
#   (',', ','),
#   ('onboarding', 'NN'),
#   ('and', 'CC'),
#   ('new', 'JJ'),
#   ('hire', 'VB'),
#   ('orientation', 'NN'),
#   ('programs', 'NNS'),
#   (',', ','),
#   ('soft', 'JJ'),
#   ('skills', 'NNS'),
#   ('and', 'CC'),
#   ('engagement', 'NN'),
#   ('activities', 'NNS'),
#   ('.', '.')],
#  [('Responsibilities/Duties:', 'NN')],
#  [('Assist', 'VB'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('design', 'NN'),
#   ('and', 'CC'),
#   ('development', 'NN'),
#   ('of', 'IN'),
#   ('training', 'VBG'),
#   ('courses', 'NNS'),
#   ('in', 'IN'),
#   ('various', 'JJ'),
#   ('formats', 'NNS'),
#   ('for', 'IN'),
#   ('internal', 'JJ'),
#   ('and', 'CC'),
#   ('remote', 'JJ'),
#   ('audiences', 'NNS'),
#   ('to', 'TO'),
#   ('fulfill', 'VB'),
#   ('training', 'VBG'),
#   ('objectives.Identify', 'NN'),
#   ('gaps', 'NNS'),
#   ('based', 'VBN'),
#   ('from', 'IN'),
#   ('observations', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('field', 'NN'),
#   ('to', 'IN'),
#   ('tailor', 'NN'),
#   ('appropriate', 'JJ'),
#   ('training', 'NN'),
#   ('content', 'NN'),
#   ('.', '.')],
#  [('Support', 'NN'),
#   ('the', 'AT'),
#   ('Development', 'NN-TL'),
#   ('of', 'IN-TL'),
#   ('Field', 'NN-TL'),
#   ('Managers', 'NN'),
#   ('around', 'IN'),
#   ('the', 'AT'),
#   ('MS', 'NN'),
#   ('Sales', 'NNS'),
#   ('Process', 'NN-TL'),
#   ('.', '.')],
#  [('Facilitate', 'NN'),
#   ('group', 'NN'),
#   ('trainings', 'NN'),
#   ('in', 'IN'),
#   ('the', 'AT'),
#   ('field', 'NN'),
#   ('and', 'CC'),
#   ('during', 'IN'),
#   ('leadership', 'NN'),
#   ('meetings', 'NNS')],
#  [('Inspect', 'VB'),
#   ('the', 'AT'),
#   ('execution', 'NN'),
#   ('of', 'IN'),
#   ('learning', 'VBG'),
#   ('directives', 'NNS'),
#   ('at', 'IN'),
#   ('the', 'AT'),
#   ('retail', 'JJ'),
#   ('level', 'NN')],
#  [('Reporting', 'NN'),
#   ('of', 'IN'),
#   ('all', 'ABN'),
#   ('interactions', 'NNS'),
#   ('and', 'CC'),
#   ('findings', 'NNS'),
#   ('on', 'IN'),
#   ('a', 'AT'),
#   ('weekly', 'JJ'),
#   ('basis', 'NN')],
#  [('Maintaining', 'VBG'),
#   ('strong', 'JJ'),
#   ('relationships', 'NNS'),
#   ('with', 'IN'),
#   ('vendors', 'NNS'),
#   ('and', 'CC'),
#   ('carriers', 'NNS'),
#   ('in', 'IN'),
#   ('home', 'NR'),
#   ('market', 'NN'),
#   ('and', 'CC'),
#   ('up', 'RP'),
#   ('to', 'IN'),
#   ('date', 'NN'),
#   ('on', 'IN'),
#   ('industry', 'NN'),
#   ('trends', 'NNS')],
#  [('Consult', 'NN'),
#   ('with', 'IN'),
#   ('Leadership', 'NN'),
#   ('on', 'IN'),
#   ('perceived', 'VBN'),
#   ('sales', 'NNS'),
#   ('skill', 'NN'),
#   ('gaps', 'NNS'),
#   ('and', 'CC'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('support', 'VB'),
#   ('the', 'AT'),
#   ('performance', 'NN'),
#   ('improvement', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('field', 'NN'),
#   ('leadership', 'NN'),
#   ('.', '.')],
#  [('Identify', 'NN'),
#   ('and', 'CC'),
#   ('source', 'NN'),
#   ('training', 'NN'),
#   ('vendors', 'NNS'),
#   ('and', 'CC'),
#   ('resources', 'NNS'),
#   ('and', 'CC'),
#   ('assist', 'VB'),
#   ('in', 'IN'),
#   ('creating', 'VBG'),
#   ('curriculum', 'NN'),
#   ('in', 'IN'),
#   ('support', 'NN'),
#   ('of', 'IN'),
#   ('learning', 'VBG'),
#   ('and', 'CC'),
#   ('development', 'NN'),
#   ('initiatives', 'NN'),
#   ('.', '.')],
#  [('Ensure', 'VB'),
#   ('learning', 'VBG'),
#   ('curriculum', 'NN'),
#   ('supports', 'NNS'),
#   ('role-specific', 'NN'),
#   ('competencies', 'NN'),
#   ('and', 'CC'),
#   ('aligns', 'NN'),
#   ('training', 'NN'),
#   ('and', 'CC'),
#   ('development', 'NN'),
#   ('activities', 'NNS'),
#   ('.', '.')],
#  [('Establishcomprehensive', 'NN'),
#   ('onboarding', 'NN'),
#   ('and', 'CC'),
#   ('new', 'JJ'),
#   ('hire', 'VB'),
#   ('orientation', 'NN'),
#   ('program', 'NN'),
#   ('to', 'IN'),
#   ('effectively', 'RB'),
#   ('support', 'VB'),
#   (',', ','),
#   ('engage', 'VB'),
#   ('and', 'CC'),
#   ('prepare', 'VB'),
#   ('new', 'JJ'),
#   ('employees', 'NNS'),
#   ('.', '.')],
#  [('Identify', 'NN'),
#   ('and', 'CC'),
#   ('assist', 'VB'),
#   ('in', 'IN'),
#   ('development', 'NN'),
#   ('of', 'IN'),
#   ('employee', 'NN'),
#   ('recognition', 'NN'),
#   ('and', 'CC'),
#   ('engagement', 'NN'),
#   ('activities', 'NNS'),
#   ('.', '.')],
#  [('Initiate', 'NN'),
#   ('pre', 'NN'),
#   ('and', 'CC'),
#   ('post', 'NN'),
#   ('communication', 'NN'),
#   ('and', 'CC'),
#   ('reinforcement', 'NN'),
#   ('of', 'IN'),
#   ('participant', 'NN'),
#   ('engagement', 'NN'),
#   ('and', 'CC'),
#   ('accountability', 'NN'),
#   ('to', 'IN'),
#   ('improve', 'VB'),
#   ('employee', 'NN'),
#   ('effectiveness', 'NN'),
#   ('.', '.')],
#  [('Proactively', 'NN'),
#   ('develop', 'VB'),
#   ('collaborative', 'NN'),
#   ('relationships', 'NNS'),
#   ('with', 'IN'),
#   ('Talent', 'NN'),
#   ('Development', 'NN-TL'),
#   (',', ','),
#   ('HR', 'NN'),
#   ('and', 'CC'),
#   ('key', 'NN'),
#   ('business', 'NN'),
#   ('leaders', 'NNS'),
#   ('to', 'TO'),
#   ('perform', 'VB'),
#   ('needs', 'NNS'),
#   ('assessments', 'NNS'),
#   ('and', 'CC'),
#   ('identify', 'VB'),
#   ('training', 'VBG'),
#   ('gaps', 'NNS'),
#   ('.', '.')],
#  [('Monitor', 'VB'),
#   ('and', 'CC'),
#   ('evaluate', 'VB'),
#   ('learning', 'VBG'),
#   ('outcomes', 'NNS'),
#   ('to', 'TO'),
#   ('effectively', 'RB'),
#   ('impact', 'NN'),
#   ('the', 'AT'),
#   ('needs', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('business', 'NN'),
#   ('.', '.')],
#  [('Evaluate', 'NN'),
#   ('the', 'AT'),
#   ('effectiveness', 'NN'),
#   ('of', 'IN'),
#   ('curriculum', 'NN'),
#   ('through', 'IN'),
#   ('course', 'NN'),
#   ('surveys', 'NNS'),
#   ('and', 'CC'),
#   ('feedback', 'NN'),
#   ('from', 'IN'),
#   ('business', 'NN'),
#   ('leaders', 'NNS'),
#   ('.', '.')],
#  [('Build', 'VB'),
#   ('and', 'CC'),
#   ('maintain', 'VB'),
#   ('a', 'AT'),
#   ('library', 'NN'),
#   ('of', 'IN'),
#   ('resources', 'NNS'),
#   ('that', 'WPS'),
#   ('address', 'NN'),
#   ('development', 'NN'),
#   ('needs', 'VBZ'),
#   ('and', 'CC'),
#   ('competencies', 'NN'),
#   ('.', '.')],
#  [('Work', 'NN'),
#   ('in', 'IN'),
#   ('partnership', 'NN'),
#   ('with', 'IN'),
#   ('instructional', 'JJ'),
#   ('designers', 'NNS'),
#   ('using', 'VBG'),
#   ('adult', 'NN'),
#   ('learning', 'VBG'),
#   ('principles', 'NNS'),
#   ('and', 'CC'),
#   ('interactivity', 'NN'),
#   ('to', 'IN'),
#   ('create', 'VB'),
#   ('and', 'CC'),
#   ('deliver', 'VB'),
#   ('blended', 'VBN'),
#   ('learning', 'VBG'),
#   ('to', 'TO'),
#   ('include', 'VB'),
#   ('classroom', 'NN'),
#   (',', ','),
#   ('e-learning', 'NN'),
#   ('and', 'CC'),
#   ('virtual', 'JJ'),
#   ('training', 'NN'),
#   ('.', '.')],
#  [('Other', 'AP'),
#   ('duties', 'NNS'),
#   ('as', 'CS'),
#   ('assigned', 'VBN'),
#   ('.', '.')],
#  [('Job', 'NP-TL'), ('Requirements:', 'NN')],
#  [('Excels', 'NN'),
#   ('in', 'IN'),
#   ('a', 'AT'),
#   ('fast-paced', 'NN'),
#   (',', ','),
#   ('service-centric', 'NN'),
#   ('environment', 'NN')],
#  [('Demonstrated', 'NN'),
#   ('experience', 'NN'),
#   ('creating', 'VBG'),
#   (',', ','),
#   ('designing', 'VBG'),
#   ('and', 'CC'),
#   ('delivering', 'VBG'),
#   ('effective', 'JJ'),
#   ('training', 'NN'),
#   ('strategies', 'NN')],
#  [('Experience', 'NN'),
#   ('in', 'IN'),
#   ('facilitating', 'VBG'),
#   ('blended', 'VBN'),
#   ('solutions', 'NNS'),
#   ('incorporating', 'VBG'),
#   ('instructor-led', 'NN'),
#   (',', ','),
#   ('online', 'NN'),
#   ('courseware', 'NN'),
#   ('and', 'CC'),
#   ('virtual', 'JJ'),
#   ('sessions', 'NNS')],
#  [('Strong', 'JJ'),
#   ('business', 'NN'),
#   ('acumen', 'NN'),
#   ('including', 'IN'),
#   ('problem', 'NN'),
#   ('solving', 'VBG'),
#   (',', ','),
#   ('critical', 'JJ'),
#   ('thinking', 'NN'),
#   ('and', 'CC'),
#   ('collaboration', 'NN'),
#   ('across', 'IN'),
#   ('multiple', 'JJ'),
#   ('functions', 'NNS'),
#   ('and', 'CC'),
#   ('departments', 'NNS')],
#  [('Ability', 'NN'),
#   ('to', 'IN'),
#   ('perform', 'VB'),
#   ('and', 'CC'),
#   ('interpret', 'VB'),
#   ('needs', 'NNS'),
#   ('analyses', 'NNS'),
#   ('and', 'CC'),
#   ('translate', 'VB'),
#   ('findings', 'NNS'),
#   ('into', 'IN'),
#   ('development', 'NN'),
#   ('strategies', 'NN')],
#  [('Adept', 'NN'),
#   ('at', 'IN'),
#   ('handling', 'VBG'),
#   ('multiple', 'JJ'),
#   ('competing', 'VBG'),
#   ('priorities', 'NNS'),
#   ('in', 'IN'),
#   ('a', 'AT'),
#   ('results-driven', 'NN'),
#   (',', ','),
#   ('time-critical', 'NN'),
#   (',', ','),
#   ('rapidly', 'RB'),
#   ('changing', 'VBG'),
#   ('environment', 'NN'),
#   ('with', 'IN'),
#   ('limited', 'VBN'),
#   ('daily', 'RB'),
#   ('oversight', 'NN')],
#  [('Ability', 'NN'),
#   ('to', 'IN'),
#   ('build', 'NN'),
#   ('relationships', 'NNS'),
#   ('across', 'IN'),
#   ('all', 'ABN'),
#   ('levels', 'NNS'),
#   ('of', 'IN'),
#   ('employees', 'NNS')],
#  [('Excellent', 'JJ'),
#   ('communication', 'NN'),
#   ('skills', 'NNS'),
#   ('written', 'VBN'),
#   (',', ','),
#   ('verbal', 'JJ'),
#   (',', ','),
#   ('interpersonal', 'JJ'),
#   ('and', 'CC'),
#   ('presentation/facilitation', 'NN')],
#  [('Strong', 'JJ'),
#   ('teamwork', 'NN'),
#   ('and', 'CC'),
#   ('partnering', 'NN'),
#   ('skills', 'NNS'),
#   ('in', 'IN'),
#   ('support', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('mission', 'NN'),
#   (',', ','),
#   ('vision', 'NN'),
#   ('and', 'CC'),
#   ('values', 'NNS'),
#   ('of', 'IN'),
#   ('MarketSource', 'NN'),
#   ('and', 'CC'),
#   ('key', 'NN'),
#   ('Talent', 'NN'),
#   ('Development', 'NN-TL'),
#   ('strategies', 'NN')],
#  [('Operates', 'NN'),
#   ('in', 'IN'),
#   ('alignment', 'NN'),
#   ('with', 'IN'),
#   ('embed', 'NN'),
#   ('D', 'NP'),
#   ('&', 'CC-TL'),
#   ('I', 'PPSS'),
#   ('strategies', 'NN'),
#   (',', ','),
#   ('topics', 'NNS'),
#   ('and', 'CC'),
#   ('resources', 'NNS'),
#   ('into', 'IN'),
#   ('training', 'VBG'),
#   ('and', 'CC'),
#   ('engagement', 'NN'),
#   ('activities', 'NNS')],
#  [('Strong', 'JJ'), ('PowerPoint', 'NN'), ('skills', 'NNS')],
#  [('experience', 'NN'),
#   ('with', 'IN'),
#   ('e-learning', 'NN'),
#   ('authoring/course', 'NN'),
#   ('development', 'NN'),
#   ('tools', 'NNS'),
#   ('a', 'AT'),
#   ('plus', 'CC')],
#  [('Ability', 'NN'),
#   ('to', 'IN'),
#   ('travel', 'NN'),
#   ('out', 'RP'),
#   ('of', 'IN'),
#   ('home', 'NR'),
#   ('market', 'NN'),
#   ('50-60', 'NN'),
#   ('%', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('time', 'NN')],
#  [('Education', 'NN'), ('and', 'CC'), ('Work', 'NN'), ('Experience:', 'NN')],
#  [('Bachelors', 'NN'),
#   ('degree', 'NN'),
#   ('with', 'IN'),
#   ('a', 'AT'),
#   ('preferred', 'VBN'),
#   ('focus', 'NN'),
#   ('on', 'IN'),
#   ('Human', 'JJ-TL'),
#   ('Resources', 'NN'),
#   (',', ','),
#   ('Organizational', 'NN'),
#   ('Development', 'NN-TL'),
#   (',', ','),
#   ('Retail', 'JJ-TL'),
#   ('Sales', 'NNS'),
#   ('Management', 'NN-TL')],
#  [('Sales', 'NNS'),
#   ('Process', 'NN-TL'),
#   ('Expert', 'NN'),
#   ('with', 'IN'),
#   ('proven', 'VBN'),
#   ('background', 'NN'),
#   ('in', 'IN'),
#   ('solution', 'NN'),
#   ('selling', 'VBG'),
#   ('and', 'CC'),
#   ('performance', 'NN'),
#   ('coaching', 'VBG')],
#  [('4-5', 'NN'),
#   ('years', 'NNS'),
#   ('in', 'IN'),
#   ('Retail', 'JJ-TL'),
#   ('Sales', 'NNS'),
#   ('Management', 'NN-TL'),
#   ('for', 'IN'),
#   ('National', 'JJ-TL'),
#   ('Retailers', 'NN')],
#  [('Superior', 'JJ'),
#   ('sales', 'NNS'),
#   ('coaching', 'VBG'),
#   ('skills', 'NNS'),
#   ('and', 'CC'),
#   ('experience', 'NN'),
#   ('designing', 'VBG'),
#   ('sales', 'NNS'),
#   ('process', 'NN'),
#   ('curriculum', 'NN'),
#   ('with', 'IN'),
#   ('a', 'AT'),
#   ('minimum', 'NN'),
#   ('of', 'IN'),
#   ('5', 'CD'),
#   ('years', 'NNS'),
#   ('experience', 'NN'),
#   ('in', 'IN'),
#   ('corporate', 'JJ'),
#   ('training', 'NN'),
#   ('environment', 'NN')],
#  [('Experience', 'NN'),
#   ('developing', 'VBG'),
#   ('onboarding', 'NN'),
#   ('and', 'CC'),
#   ('orientation', 'NN'),
#   ('programs', 'NNS')],
#  [('FIELD', 'NN'), ('MARKETING', 'NN'), ('TRAINER', 'NN')],
#  [('This', 'DT'),
#   ('job', 'NN'),
#   ('reports', 'NNS'),
#   ('to', 'TO'),
#   ('the', 'AT'),
#   ('Training', 'NN-TL'),
#   ('Manager', 'NN-TL'),
#   ('with', 'IN'),
#   ('a', 'AT'),
#   ('dotted', 'VBN'),
#   ('line', 'NN'),
#   ('to', 'IN'),
#   ('heads', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('Retail', 'JJ-TL'),
#   ('andCanvass', 'NN'),
#   ('teams.We', 'NN'),
#   ('need', 'MD'),
#   ('a', 'AT'),
#   ('focused', 'VBN'),
#   ('individual', 'NN'),
#   ('working', 'VBG'),
#   ('with', 'IN'),
#   ('our', 'PP$'),
#   ('field', 'NN'),
#   ('marketing', 'VBG'),
#   ('reps', 'NNS'),
#   ('to', 'TO'),
#   ('help', 'VB'),
#   ('identify', 'VB'),
#   ('andaddress', 'NN'),
#   ('their', 'PP$'),
#   ('weaknessesenabling', 'NN'),
#   ('them', 'PPO'),
#   ('to', 'TO'),
#   ('increase', 'VB'),
#   ('their', 'PP$'),
#   ('performance', 'NN'),
#   ('each', 'DT'),
#   ('monthposition', 'NN'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('responsible', 'JJ'),
#   ('for', 'IN'),
#   ('supporting', 'VBG'),
#   ('both', 'ABX'),
#   ('the', 'AT'),
#   ('Retail', 'JJ-TL'),
#   ('and', 'CC'),
#   ('Canvassing', 'NN'),
#   ('groups', 'NNS'),
#   ('of', 'IN'),
#   ('theField', 'NN'),
#   ('Marketing', 'VBG-TL'),
#   ('organization', 'NN'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('position', 'NN'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('on', 'IN'),
#   ('the', 'AT'),
#   ('road', 'NN'),
#   ('approximately', 'RB'),
#   ('65', 'CD'),
#   ('%', 'NN'),
#   ('of', 'IN'),
#   ('thetime', 'NN'),
#   (',', ','),
#   ('in', 'IN'),
#   ('a', 'AT'),
#   ('combination', 'NN'),
#   ('of', 'IN'),
#   ('local', 'JJ'),
#   ('and', 'CC'),
#   ('nationwide', 'JJ'),
#   ('travel', 'NN'),
#   ('.', '.')],
#  [('Who', 'WPS'), ('We', 'PPSS'), ('Are:', 'NN')],
#  [('If', 'CS'),
#   ('change', 'NN'),
#   ('means', 'VBZ'),
#   ('solving', 'VBG'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('biggest', 'JJT'),
#   ('challenges', 'VBZ'),
#   ('of', 'IN'),
#   ('our', 'PP$'),
#   ('time', 'NN'),
#   ('by', 'IN'),
#   ('reinventing', 'NN'),
#   ('the', 'AT'),
#   ('way', 'NN'),
#   ('people', 'NNS'),
#   ('power', 'VB'),
#   ('their', 'PP$'),
#   ('homes', 'NNS'),
#   (',', ','),
#   ('then', 'RB'),
#   ('we', 'PPSS'),
#   ('say', 'VB'),
#   ('bring', 'VB'),
#   ('it', 'PPO'),
#   ('on.It', 'NN'),
#   ('doesnt', 'NN'),
#   ('hurt', 'VB'),
#   ('that', 'CS'),
#   ('were', 'BED'),
#   ('reducing', 'VBG'),
#   ('carbon', 'NN'),
#   ('emissions', 'NN'),
#   (',', ','),
#   ('adding', 'VBG'),
#   ('new', 'JJ'),
#   ('jobs', 'NNS'),
#   ('to', 'TO'),
#   ('the', 'AT'),
#   ('economy', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('having', 'HVG'),
#   ('fun', 'NN'),
#   ('while', 'CS'),
#   ('doing', 'VBG'),
#   ('it', 'PPO'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('2007', 'NN'),
#   (',', ','),
#   ('Sunrun', 'NN'),
#   ('co-Founders', 'NN'),
#   ('Ed', 'NP'),
#   ('Fenster', 'NP'),
#   ('and', 'CC'),
#   ('Lynn', 'NP'),
#   ('Jurich', 'NN'),
#   ('set', 'VBN'),
#   ('out', 'RP'),
#   ('to', 'IN'),
#   ('make', 'VB'),
#   ('home', 'NR'),
#   ('solar', 'JJ'),
#   ('mainstream', 'NN'),
#   ('.', '.')],
#  [('Upfront', 'NN'),
#   ('cost', 'NN'),
#   ('was', 'BEDZ'),
#   ('a', 'AT'),
#   ('huge', 'JJ'),
#   ('barrier', 'NN'),
#   ('to', 'IN'),
#   ('home', 'NR'),
#   ('solar', 'JJ'),
#   ('adoption', 'NN'),
#   (',', ','),
#   ('so', 'CS'),
#   ('they', 'PPSS'),
#   ('invented', 'VBN'),
#   ('the', 'AT'),
#   ('model', 'NN'),
#   ('now', 'RB'),
#   ('known', 'VBN'),
#   ('as', 'CS'),
#   ("'solar", 'NN'),
#   ('service', 'NN'),
#   ('.', '.')],
#  [("'", "'"),
#   ('Sunrun', 'NN'),
#   ('allows', 'VBZ'),
#   ('homeowners', 'NNS'),
#   ('to', 'TO'),
#   ('pay', 'VB'),
#   ('for', 'IN'),
#   ('solar', 'JJ'),
#   ('power', 'NN'),
#   (',', ','),
#   ('not', '*'),
#   ('the', 'AT'),
#   ('panels', 'NNS'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('means', 'VBZ'),
#   ('Sunrun', 'NN'),
#   ('owns', 'VBZ'),
#   (',', ','),
#   ('maintains', 'VBZ'),
#   (',', ','),
#   ('and', 'CC'),
#   ('monitors', 'NNS'),
#   ('the', 'AT'),
#   ('system', 'NN'),
#   ('while', 'CS'),
#   ('homeowners', 'NNS'),
#   ('pay', 'VB'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('electricity', 'NN'),
#   ('it', 'PPS'),
#   ('produces', 'VBZ'),
#   ('.', '.')],
#  [('Each', 'DT'),
#   ('business', 'NN'),
#   ('day', 'NN'),
#   (',', ','),
#   ('we', 'PPSS'),
#   ('install', 'VB'),
#   ('$', 'NN'),
#   ('2', 'CD'),
#   ('million', 'CD'),
#   ('worth', 'NN'),
#   ('of', 'IN'),
#   ('solar', 'JJ'),
#   ('and', 'CC'),
#   ('facilitate', 'VB'),
#   ('one', 'CD'),
#   ('solar', 'JJ'),
#   ('installation', 'NN'),
#   ('every', 'AT'),
#   ('10', 'CD'),
#   ('minutes', 'NNS'),
#   ('.', '.')],
#  [('Our', 'PP$'),
#   ('network', 'NN'),
#   ('of', 'IN'),
#   ('more', 'AP'),
#   ('than', 'IN'),
#   ('30', 'CD'),
#   ('leading', 'VBG'),
#   ('solar', 'JJ'),
#   ('installers', 'NN'),
#   ('employs', 'VBZ'),
#   ('more', 'QL'),
#   ('than', 'CS'),
#   ('3,000', 'CD'),
#   ('people', 'NNS'),
#   ('.', '.')],
#  [('Key', 'NN-HL'),
#   ('focuses', 'VBZ'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('job:', 'NN')],
#  [('Travel', 'NN'),
#   ('around', 'IN'),
#   ('to', 'IN'),
#   ('branches', 'NNS'),
#   ('with', 'IN'),
#   ('solar', 'JJ'),
#   ('stations', 'NNS')],
#  [('Train', 'NN-TL'),
#   ('on', 'IN'),
#   ('Design', 'NN-TL'),
#   ('tool', 'NN'),
#   ('and', 'CC'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('effectively', 'RB'),
#   ('use', 'VB'),
#   ('the', 'AT'),
#   ('Solar', 'JJ-TL'),
#   ('Station', 'NN-TL'),
#   ('.', '.')],
#  [('Train', 'NN-TL'),
#   ('for', 'IN'),
#   ('best', 'JJT'),
#   ('practices', 'NNS'),
#   ('at', 'IN'),
#   ('Home', 'NN-TL'),
#   ('Depots', 'NN'),
#   ('and', 'CC'),
#   ('Costcos', 'NN')],
#  [('Full', 'JJ'),
#   ('Solar', 'JJ-TL'),
#   ('Station', 'NN-TL'),
#   ('deployment', 'NN'),
#   ('on', 'IN'),
#   ('9.15', 'NN')],
#  [('Assist', 'VB'),
#   ('in', 'IN'),
#   ('strengthening', 'VBG'),
#   ('the', 'AT'),
#   ('Field', 'NN-TL'),
#   ('Marketing', 'VBG-TL'),
#   ('Supervisors', 'NNS-TL'),
#   ('and', 'CC'),
#   ('Managers', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('Canvass', 'NN'),
#   ('manager', 'NN'),
#   ('role', 'NN'),
#   ('.', '.')],
#  [('Train', 'NN-TL'),
#   ('and', 'CC'),
#   ('coach', 'NN'),
#   ('Field', 'NN-TL'),
#   ('Marketing', 'VBG-TL'),
#   ('Supervisors', 'NNS-TL'),
#   ('to', 'TO'),
#   ('improve', 'VB'),
#   ('training', 'VBG'),
#   ('capabilities', 'NNS')],
#  [('Drive', 'NN-TL'), ('consistent', 'JJ'), ('messaging', 'NN')],
#  [('Drive', 'NN-TL'),
#   ('consistent', 'JJ'),
#   ('sales', 'NNS'),
#   ('process', 'NN')],
#  [('The', 'AT'),
#   ('trainer', 'NN'),
#   ('should', 'MD'),
#   ('be', 'BE'),
#   ('able', 'JJ'),
#   ('to:', 'NN')],
#  [('Conduct', 'VB'),
#   ('T3s', 'NN'),
#   ('to', 'IN'),
#   ('the', 'AT'),
#   ('Field', 'NN-TL'),
#   ('Marketing', 'VBG-TL'),
#   ('Supervisors', 'NNS-TL'),
#   ('to', 'TO'),
#   ('continue', 'VB'),
#   ('to', 'TO'),
#   ('train/remind', 'NN'),
#   ('themof', 'NN'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('train', 'VB'),
#   ('their', 'PP$'),
#   ('teams', 'NNS'),
#   ('.', '.')],
#  [('Develop/adapt', 'NN'),
#   ('training', 'NN'),
#   ('materialon', 'NN'),
#   ('relevant', 'JJ'),
#   ('topics', 'NNS'),
#   ('like', 'CS'),
#   ("'how", 'NN'),
#   ('to', 'IN'),
#   ('approach', 'NN'),
#   ('acustomer', 'NN'),
#   (',', ','),
#   ("'", "'"),
#   ('or', 'CC'),
#   ("'active", 'NN'),
#   ('listening', 'VBG'),
#   (',', ','),
#   ("'", "'"),
#   ('or', 'CC'),
#   ("'5", 'NN'),
#   ('things', 'NNS'),
#   ('you', 'PPSS'),
#   ('should', 'MD'),
#   ('knowabout', 'NN'),
#   ('your', 'PP$'),
#   ('local', 'JJ'),
#   ('utility', 'NN'),
#   ("'", "'")],
#  [('Develop', 'VB'),
#   ('training', 'VBG'),
#   ('for', 'IN'),
#   ('use', 'NN'),
#   ('and', 'CC'),
#   ('best', 'JJT'),
#   ('practices', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'AT'),
#   ('SolarStation', 'NN'),
#   ('.', '.')],
#  [('Deliver', 'NN'),
#   ('Classroom', 'NN'),
#   ('training', 'NN'),
#   ('and', 'CC'),
#   ('webinar', 'NN'),
#   ('training', 'NN')],
#  [('Deliver', 'NN'),
#   ('management', 'NN'),
#   ('training', 'NN'),
#   ('to', 'IN'),
#   ('Field', 'NN-TL'),
#   ('Marketing', 'VBG-TL'),
#   ('Leads', 'VBZ'),
#   (',', ','),
# ...
#   ('society', 'NN'),
#   ('.', '.')],
#  [('We', 'PPSS'),
#   ('engage', 'VB'),
#   ('marketing', 'VBG'),
#   (',', ','),
#   ('technology', 'NN'),
#   (',', ','),
#   ('strategy', 'NN'),
#   (',', ','),
#   ('design', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('HR', 'NN'),
#   ('management', 'NN'),
#   ('professionals', 'NNS'),
#   ('on', 'IN'),
#   ('pro', 'NN'),
#   ('bono', 'NN'),
#   ('projects', 'NNS'),
#   (',', ','),
#   ('called', 'VBN'),
#   ('Service', 'NN-TL'),
#   ('Grants', 'NN'),
#   ('that', 'CS'),
#   ('benefit', 'NN'),
#   ('local', 'NN'),
#   ('nonprofits', 'NN'),
#   ('.', '.')],
#  [('Our', 'PP$'),
#   ('goal', 'NN'),
#   ('is', 'BEZ'),
#   ('to', 'TO'),
#   ('ensure', 'VB'),
#   ('that', 'CS'),
#   ('one', 'CD'),
#   ('day', 'NN'),
#   ('all', 'ABN'),
#   ('organizations', 'NNS'),
#   ('with', 'IN'),
#   ('promising', 'VBG'),
#   ('solutions', 'NNS'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('equipped', 'VBN'),
#   ('to', 'TO'),
#   ('successfully', 'RB'),
#   ('take', 'VB'),
#   ('on', 'IN'),
#   ('urgent', 'JJ'),
#   ('social', 'JJ'),
#   ('challenges', 'VBZ'),
#   ('.', '.')],
#  [('To', 'TO'),
#   ('date', 'VB'),
#   (',', ','),
#   ('we', 'PPSS'),
#   ('have', 'HV'),
#   ('engaged', 'VBN'),
#   ('close', 'RB'),
#   ('to', 'IN'),
#   ('5,000', 'CD'),
#   ('professionals', 'NNS'),
#   ('on', 'IN'),
#   ('close', 'JJ'),
#   ('to', 'TO'),
#   ('2,000', 'CD'),
#   ('pro', 'NN'),
#   ('bono', 'NN'),
#   ('projects', 'NNS'),
#   ('benefiting', 'NN'),
#   ('education', 'NN'),
#   (',', ','),
#   ('health', 'NN'),
#   (',', ','),
#   ('environment', 'NN'),
#   (',', ','),
#   ('social', 'JJ'),
#   ('service', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('arts', 'NNS'),
#   ('initiatives', 'NN'),
#   ('.', '.')],
#  [('Now', 'RB'),
#   ('it', 'PPS'),
#   ("'s", 'NN'),
#   ('your', 'PP$'),
#   ('turn', 'NN'),
#   ('to', 'IN'),
#   ('join', 'VB'),
#   ('the', 'AT'),
#   ('movement', 'NN'),
#   ('and', 'CC'),
#   ('Make', 'VB'),
#   ('It', 'PPS'),
#   ('Matter', 'NN-TL-HL'),
#   ('&', 'CC-TL'),
#   ('copy', 'NN')],
#  [('.', '.')],
#  [('The', 'AT'),
#   ('Brand', 'NN'),
#   ('Strategist', 'NN'),
#   ('is', 'BEZ'),
#   ('the', 'AT'),
#   ('most', 'QL'),
#   ('experienced', 'VBN'),
#   ('branding', 'NN'),
#   ('professional', 'JJ'),
#   ('on', 'IN'),
#   ('his', 'PP$'),
#   ('or', 'CC'),
#   ('her', 'PP$'),
#   ('team', 'NN'),
#   ('and', 'CC'),
#   ('serves', 'VBZ'),
#   ('as', 'CS'),
#   ('a', 'AT'),
#   ('strategic', 'JJ'),
#   ('expert', 'NN'),
#   ('to', 'IN'),
#   ('the', 'AT'),
#   ('nonprofit', 'JJ'),
#   ("'s", 'NN'),
#   ('executive', 'NN'),
#   ('staff', 'NN'),
#   ('and', 'CC'),
#   ('board', 'NN'),
#   ('members', 'NNS'),
#   ('.', '.')],
#  [('You', 'PPSS'),
#   ("'ll", 'NN'),
#   ('work', 'NN'),
#   ('as', 'CS'),
#   ('a', 'AT'),
#   ('content', 'NN'),
#   ('leader', 'NN'),
#   ('for', 'IN'),
#   ('a', 'AT'),
#   ('key', 'NN'),
#   ('messages', 'NNS'),
#   (',', ','),
#   ('visual', 'JJ'),
#   ('identity', 'NN'),
#   (',', ','),
#   ('or', 'CC'),
#   ('naming', 'VBG'),
#   ('project', 'NN'),
#   ('for', 'IN'),
#   ('a', 'AT'),
#   ('nonprofit', 'JJ'),
#   ('that', 'CS'),
#   ('needs', 'VBZ'),
#   ('a', 'AT'),
#   ('branding', 'NN'),
#   ('refresh', 'VB'),
#   ('.', '.')],
#  [('You', 'PPSS'),
#   ('can', 'MD'),
#   ('also', 'RB'),
#   ('provide', 'VB'),
#   ('your', 'PP$'),
#   ('expertise', 'NN'),
#   ('directly', 'RB'),
#   ('through', 'IN'),
#   ('our', 'PP$'),
#   ('online', 'NN'),
#   ('forums', 'NNS'),
#   ('&', 'CC'),
#   ('mdash', 'NN')],
#  [('do', 'DO'),
#   ('some', 'DTI'),
#   ('micro-bono', 'NN'),
#   ('in', 'IN'),
#   ('your', 'PP$'),
#   ('spare', 'JJ'),
#   ('time', 'NN'),
#   ('!', '.')],
#  [('Do', 'DO'),
#   ('good', 'RB'),
#   ('for', 'IN'),
#   ('your', 'PP$'),
#   ('community', 'NN'),
#   ('while', 'CS'),
#   ('using', 'VBG'),
#   ('your', 'PP$'),
#   ('professional', 'JJ'),
#   ('expertise', 'NN'),
#   ('and', 'CC'),
#   ('working', 'VBG'),
#   ('with', 'IN'),
#   ('talented', 'JJ'),
#   ('peers', 'NNS'),
#   ('on', 'IN'),
#   ('a', 'AT'),
#   ('highly', 'QL'),
#   ('structured', 'VBN'),
#   ('pro', 'NN'),
#   ('bono', 'NN'),
#   ('project', 'NN'),
#   ('.', '.')],
#  [('We', 'PPSS'),
#   ('make', 'VB'),
#   ('it', 'PPO'),
#   ('easy', 'RB'),
#   ('to', 'IN'),
#   ('make', 'VB'),
#   ('a', 'AT'),
#   ('difference', 'NN'),
#   ('.', '.')],
#  [('Taproot', 'NN'),
#   ('Foundation', 'NN-TL'),
#   ('is', 'BEZ'),
#   ('a', 'AT'),
#   ('nonprofit', 'JJ'),
#   ('organization', 'NN'),
#   ('that', 'CS'),
#   ('makes', 'VBZ'),
#   ('business', 'NN'),
#   ('talent', 'NN'),
#   ('available', 'JJ'),
#   ('to', 'TO'),
#   ('organizations', 'NNS'),
#   ('working', 'VBG'),
#   ('to', 'TO'),
#   ('improve', 'VB'),
#   ('society', 'NN'),
#   ('.', '.')],
#  [('We', 'PPSS'),
#   ('engage', 'VB'),
#   ('marketing', 'VBG'),
#   (',', ','),
#   ('technology', 'NN'),
#   (',', ','),
#   ('strategy', 'NN'),
#   (',', ','),
#   ('design', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('HR', 'NN'),
#   ('management', 'NN'),
#   ('professionals', 'NNS'),
#   ('in', 'IN'),
#   ('pro', 'NN'),
#   ('bono', 'NN'),
#   ('projects', 'NNS'),
#   (',', ','),
#   ('called', 'VBN'),
#   ('Service', 'NN-TL'),
#   ('Grants', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('benefit', 'NN'),
#   ('local', 'NN'),
#   ('nonprofits', 'NN'),
#   ('.', '.')],
#  [('Our', 'PP$'),
#   ('goal', 'NN'),
#   ('is', 'BEZ'),
#   ('to', 'TO'),
#   ('ensure', 'VB'),
#   ('that', 'CS'),
#   ('one', 'CD'),
#   ('day', 'NN'),
#   ('all', 'ABN'),
#   ('organizations', 'NNS'),
#   ('with', 'IN'),
#   ('promising', 'VBG'),
#   ('solutions', 'NNS'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('equipped', 'VBN'),
#   ('to', 'TO'),
#   ('successfully', 'RB'),
#   ('take', 'VB'),
#   ('on', 'IN'),
#   ('urgent', 'JJ'),
#   ('social', 'JJ'),
#   ('challenges', 'VBZ'),
#   ('.', '.')],
#  [('To', 'TO'),
#   ('date', 'VB'),
#   (',', ','),
#   ('we', 'PPSS'),
#   ('have', 'HV'),
#   ('engaged', 'VBN'),
#   ('over', 'IN'),
#   ('4,500', 'CD'),
#   ('professionals', 'NNS'),
#   ('on', 'IN'),
#   ('more', 'AP'),
#   ('than', 'IN'),
#   ('1,000', 'CD'),
#   ('pro', 'NN'),
#   ('bono', 'NN'),
#   ('projects', 'NNS'),
#   ('benefiting', 'NN'),
#   ('education', 'NN'),
#   (',', ','),
#   ('health', 'NN'),
#   (',', ','),
#   ('environment', 'NN'),
#   (',', ','),
#   ('social', 'JJ'),
#   ('service', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('arts', 'NNS'),
#   ('initiatives', 'NN'),
#   ('.', '.')],
#  [('Pro', 'FW-IN-TL'),
#   ('Bono', 'NN'),
#   ('Graphic', 'JJ-TL'),
#   ('Designers', 'NNS-TL'),
#   ('Needed', 'NN')],
#  [('Taproot', 'NN'),
#   ('Graphic', 'JJ-TL'),
#   ('Designers', 'NNS-TL'),
#   ('are', 'BER'),
#   ('responsible', 'JJ'),
#   ('for', 'IN'),
#   ('the', 'AT'),
#   ('visual', 'JJ'),
#   ('design', 'NN'),
#   ('of', 'IN'),
#   ('a', 'AT'),
#   ('brochure', 'NN'),
#   ('or', 'CC'),
#   ('branding', 'NN'),
#   ('collateral', 'NN'),
#   ('for', 'IN'),
#   ('a', 'AT'),
#   ('nonprofit', 'JJ'),
#   ('.', '.')],
#  [('Lend', 'VB-TL'),
#   ('your', 'PP$'),
#   ('Marketing', 'VBG-TL'),
#   ('Skills', 'NN'),
#   ('to', 'IN'),
#   ('Lead', 'VB'),
#   ('.', '.')],
#  [('Do', 'DO'),
#   ('good', 'RB'),
#   ('for', 'IN'),
#   ('your', 'PP$'),
#   ('community', 'NN'),
#   ('while', 'CS'),
#   ('using', 'VBG'),
#   ('your', 'PP$'),
#   ('professional', 'JJ'),
#   ('expertise', 'NN'),
#   ('and', 'CC'),
#   ('work', 'VB'),
#   ('with', 'IN'),
#   ('talented', 'JJ'),
#   ('peers', 'NNS'),
#   ('on', 'IN'),
#   ('a', 'AT'),
#   ('highly', 'QL'),
#   ('structured', 'VBN'),
#   ('pro', 'NN'),
#   ('bono', 'NN'),
#   ('project', 'NN'),
#   ('!', '.')],
#  [('Taproot', 'NN'),
#   ('makes', 'VBZ'),
#   ('it', 'PPO'),
#   ('easy', 'RB'),
#   ('to', 'IN'),
#   ('make', 'VB'),
#   ('a', 'AT'),
#   ('difference', 'NN'),
#   ('.', '.')],
#  [('Taproot', 'NN'),
#   ('Foundation', 'NN-TL'),
#   ('is', 'BEZ'),
#   ('a', 'AT'),
#   ('nonprofit', 'JJ'),
#   ('organization', 'NN'),
#   ('that', 'CS'),
#   ('makes', 'VBZ'),
#   ('business', 'NN'),
#   ('talent', 'NN'),
#   ('available', 'JJ'),
#   ('to', 'TO'),
#   ('organizations', 'NNS'),
#   ('that', 'WPS'),
#   ('are', 'BER'),
#   ('working', 'VBG'),
#   ('to', 'TO'),
#   ('improve', 'VB'),
#   ('society', 'NN'),
#   ('.', '.')],
#  [('We', 'PPSS'),
#   ('engage', 'VB'),
#   ('marketing', 'VBG'),
#   (',', ','),
#   ('technology', 'NN'),
#   (',', ','),
#   ('strategy', 'NN'),
#   (',', ','),
#   ('design', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('HR', 'NN'),
#   ('management', 'NN'),
#   ('professionals', 'NNS'),
#   ('on', 'IN'),
#   ('pro', 'NN'),
#   ('bono', 'NN'),
#   ('projects', 'NNS'),
#   (',', ','),
#   ('called', 'VBN'),
#   ('Service', 'NN-TL'),
#   ('Grants', 'NN'),
#   ('that', 'CS'),
#   ('benefit', 'NN'),
#   ('local', 'NN'),
#   ('nonprofits', 'NN'),
#   ('.', '.')],
#  [('Our', 'PP$'),
#   ('goal', 'NN'),
#   ('is', 'BEZ'),
#   ('to', 'TO'),
#   ('ensure', 'VB'),
#   ('that', 'CS'),
#   ('one', 'CD'),
#   ('day', 'NN'),
#   ('all', 'ABN'),
#   ('organizations', 'NNS'),
#   ('with', 'IN'),
#   ('promising', 'VBG'),
#   ('solutions', 'NNS'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('equipped', 'VBN'),
#   ('to', 'TO'),
#   ('successfully', 'RB'),
#   ('take', 'VB'),
#   ('on', 'IN'),
#   ('urgent', 'JJ'),
#   ('social', 'JJ'),
#   ('challenges', 'VBZ'),
#   ('.', '.')],
#  [('To', 'TO'),
#   ('date', 'VB'),
#   (',', ','),
#   ('we', 'PPSS'),
#   ('have', 'HV'),
#   ('engaged', 'VBN'),
#   ('close', 'RB'),
#   ('to', 'IN'),
#   ('5,000', 'CD'),
#   ('professionals', 'NNS'),
#   ('on', 'IN'),
#   ('close', 'JJ'),
#   ('to', 'TO'),
#   ('2,000', 'CD'),
#   ('pro', 'NN'),
#   ('bono', 'NN'),
#   ('projects', 'NNS'),
#   ('benefiting', 'NN'),
#   ('education', 'NN'),
#   (',', ','),
#   ('health', 'NN'),
#   (',', ','),
#   ('environment', 'NN'),
#   (',', ','),
#   ('social', 'JJ'),
#   ('service', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('arts', 'NNS'),
#   ('initiatives', 'NN'),
#   ('.', '.')],
#  [('Now', 'RB'),
#   ('it', 'PPS'),
#   ("'s", 'NN'),
#   ('your', 'PP$'),
#   ('turn', 'NN'),
#   ('to', 'IN'),
#   ('join', 'VB'),
#   ('the', 'AT'),
#   ('movement', 'NN'),
#   ('and', 'CC'),
#   ('Make', 'VB'),
#   ('It', 'PPS'),
#   ('Matter', 'NN-TL-HL'),
#   ('&', 'CC-TL'),
#   ('copy', 'NN')],
#  [('.', '.')],
#  [('Pro', 'FW-IN-TL'),
#   ('Bono', 'NN'),
#   ('Account', 'NN'),
#   ('Directors', 'NNS-TL'),
#   ('Needed', 'NN')],
#  [('Taproot', 'NN'),
#   ('Account', 'NN'),
#   ('Directors', 'NNS-TL'),
#   ('lead', 'VB'),
#   ('teams', 'NNS'),
#   ('of', 'IN'),
#   ('5-6', 'CD'),
#   ('pro', 'NN'),
#   ('bono', 'NN'),
#   ('consultants', 'NNS'),
#   ('.', '.')],
#  [('On', 'IN'),
#   ('a', 'AT'),
#   ('project', 'NN'),
#   (',', ','),
#   ('the', 'AT'),
#   ('Account', 'NN'),
#   ('Director', 'NN-TL'),
#   ('staffs', 'NNS'),
#   ('the', 'AT'),
#   ('team', 'NN'),
#   (',', ','),
#   ('manages', 'VBZ'),
#   ('relationships', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('keeps', 'VBZ'),
#   ('a', 'AT'),
#   ("bird's-eye", 'NN'),
#   ('view', 'NN'),
#   ('of', 'IN'),
#   ('the', 'AT'),
#   ('project', 'NN'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('Account', 'NN'),
#   ('Director', 'NN-TL'),
#   ('also', 'RB'),
#   ('works', 'VBZ'),
#   ('with', 'IN'),
#   ('a', 'AT'),
#   ('Taproot', 'NN'),
#   ('Program', 'NN-TL'),
#   ('Manager', 'NN-TL'),
#   ('to', 'TO'),
#   ('track', 'VB'),
#   ('progress', 'NN'),
#   (',', ','),
#   ('resolve', 'VB'),
#   ('challenges', 'VBZ'),
#   (',', ','),
#   ('and', 'CC'),
#   ('ensure', 'VB'),
#   ('the', 'AT'),
#   ('successful', 'JJ'),
#   ('completion', 'NN'),
#   ('of', 'IN'),
#   ('each', 'DT'),
#   ('project', 'NN'),
#   ('.', '.')],
#  [('You', 'PPSS'),
#   ('can', 'MD'),
#   ('also', 'RB'),
#   ('provide', 'VB'),
#   ('your', 'PP$'),
#   ('expertise', 'NN'),
#   ('directly', 'RB'),
#   ('through', 'IN'),
#   ('our', 'PP$'),
#   ('online', 'NN'),
#   ('forums', 'NNS'),
#   ('&', 'CC'),
#   ('mdash', 'NN')],
#  [('do', 'DO'),
#   ('some', 'DTI'),
#   ('micro-bono', 'NN'),
#   ('in', 'IN'),
#   ('your', 'PP$'),
#   ('spare', 'JJ'),
#   ('time', 'NN'),
#   ('!', '.')],
#  [('Do', 'DO'),
#   ('Good', 'JJ'),
#   (':', ':'),
#   ('Enhance', 'NN'),
#   ('A', 'NN'),
#   ('Non', 'FW-*'),
#   ('Profit', 'NN'),
#   ("'s", 'NN'),
#   ('Website', 'NN')],
#  [('Do', 'DO'),
#   ('good', 'RB'),
#   ('for', 'IN'),
#   ('your', 'PP$'),
#   ('community', 'NN'),
#   ('while', 'CS'),
#   ('using', 'VBG'),
#   ('your', 'PP$'),
#   ('professional', 'JJ'),
#   ('expertise', 'NN'),
#   ('and', 'CC'),
#   ('work', 'VB'),
#   ('with', 'IN'),
#   ('talented', 'JJ'),
#   ('peers', 'NNS'),
#   ('on', 'IN'),
#   ('a', 'AT'),
#   ('highly', 'QL'),
#   ('structured', 'VBN'),
#   ('pro', 'NN'),
#   ('bono', 'NN'),
#   ('project', 'NN'),
#   ('!', '.')],
#  [('Taproot', 'NN'),
#   ('makes', 'VBZ'),
#   ('it', 'PPO'),
#   ('easy', 'RB'),
#   ('to', 'IN'),
#   ('make', 'VB'),
#   ('a', 'AT'),
#   ('difference', 'NN'),
#   ('.', '.')],
#  [('Taproot', 'NN'),
#   ('Foundation', 'NN-TL'),
#   ('is', 'BEZ'),
#   ('a', 'AT'),
#   ('nonprofit', 'JJ'),
#   ('organization', 'NN'),
#   ('that', 'CS'),
#   ('makes', 'VBZ'),
#   ('business', 'NN'),
#   ('talent', 'NN'),
#   ('available', 'JJ'),
#   ('to', 'TO'),
#   ('organizations', 'NNS'),
#   ('that', 'WPS'),
#   ('are', 'BER'),
#   ('working', 'VBG'),
#   ('to', 'TO'),
#   ('improve', 'VB'),
#   ('society', 'NN'),
#   ('.', '.')],
#  [('We', 'PPSS'),
#   ('engage', 'VB'),
#   ('marketing', 'VBG'),
#   (',', ','),
#   ('technology', 'NN'),
#   (',', ','),
#   ('strategy', 'NN'),
#   (',', ','),
#   ('design', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('HR', 'NN'),
#   ('management', 'NN'),
#   ('professionals', 'NNS'),
#   ('on', 'IN'),
#   ('pro', 'NN'),
#   ('bono', 'NN'),
#   ('projects', 'NNS'),
#   (',', ','),
#   ('called', 'VBN'),
#   ('Service', 'NN-TL'),
#   ('Grants', 'NN'),
#   ('that', 'CS'),
#   ('benefit', 'NN'),
#   ('local', 'NN'),
#   ('nonprofits', 'NN'),
#   ('.', '.')],
#  [('Our', 'PP$'),
#   ('goal', 'NN'),
#   ('is', 'BEZ'),
#   ('to', 'TO'),
#   ('ensure', 'VB'),
#   ('that', 'CS'),
#   ('one', 'CD'),
#   ('day', 'NN'),
#   ('all', 'ABN'),
#   ('organizations', 'NNS'),
#   ('with', 'IN'),
#   ('promising', 'VBG'),
#   ('solutions', 'NNS'),
#   ('will', 'MD'),
#   ('be', 'BE'),
#   ('equipped', 'VBN'),
#   ('to', 'TO'),
#   ('successfully', 'RB'),
#   ('take', 'VB'),
#   ('on', 'IN'),
#   ('urgent', 'JJ'),
#   ('social', 'JJ'),
#   ('challenges', 'VBZ'),
#   ('.', '.')],
#  [('To', 'TO'),
#   ('date', 'VB'),
#   (',', ','),
#   ('we', 'PPSS'),
#   ('have', 'HV'),
#   ('engaged', 'VBN'),
#   ('close', 'RB'),
#   ('to', 'IN'),
#   ('5,000', 'CD'),
#   ('professionals', 'NNS'),
#   ('on', 'IN'),
#   ('close', 'JJ'),
#   ('to', 'TO'),
#   ('2,000', 'CD'),
#   ('pro', 'NN'),
#   ('bono', 'NN'),
#   ('projects', 'NNS'),
#   ('benefiting', 'NN'),
#   ('education', 'NN'),
#   (',', ','),
#   ('health', 'NN'),
#   (',', ','),
#   ('environment', 'NN'),
#   (',', ','),
#   ('social', 'JJ'),
#   ('service', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('arts', 'NNS'),
#   ('initiatives', 'NN'),
#   ('.', '.')],
#  [('Now', 'RB'),
#   ('it', 'PPS'),
#   ("'s", 'NN'),
#   ('your', 'PP$'),
#   ('turn', 'NN'),
#   ('to', 'IN'),
#   ('join', 'VB'),
#   ('the', 'AT'),
#   ('movement', 'NN'),
#   ('and', 'CC'),
#   ('Make', 'VB'),
#   ('It', 'PPS'),
#   ('Matter', 'NN-TL-HL'),
#   ('&', 'CC-TL'),
#   ('copy', 'NN')],
#  [('.', '.')],
#  [('Pro', 'FW-IN-TL'),
#   ('Bono', 'NN'),
#   ('Web', 'NN'),
#   ('Content', 'NN'),
#   ('Managers/Writers', 'NN'),
#   ('Needed', 'NN')],
#  [('A', 'AT'),
#   ('Taproot', 'NN'),
#   ('Content', 'NN'),
#   ('Manager', 'NN-TL'),
#   ('assists', 'NNS'),
#   ('the', 'AT'),
#   ('nonprofit', 'JJ'),
#   ('client', 'NN'),
#   ('in', 'IN'),
#   ('gathering', 'VBG'),
#   (',', ','),
#   ('organizing', 'VBG'),
#   (',', ','),
#   ('and', 'CC'),
#   ('creating', 'VBG'),
#   ('copy', 'NN'),
#   ('for', 'IN'),
#   ('their', 'PP$'),
#   ('website', 'NN'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('Content', 'NN'),
#   ('Manager', 'NN-TL'),
#   ('creates', 'VBZ'),
#   ('some', 'DTI'),
#   ('copy', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('primarily', 'RB'),
#   ('assists', 'NNS'),
#   ('the', 'AT'),
#   ('client', 'NN'),
#   ('in', 'IN'),
#   ('conducting', 'VBG'),
#   ('a', 'AT'),
#   ('content', 'NN'),
#   ('audit', 'NN'),
#   (',', ','),
#   ('creating', 'VBG'),
#   ('a', 'AT'),
#   ('content', 'NN'),
#   ('outline', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('developing', 'VBG'),
#   ('a', 'AT'),
#   ('content', 'NN'),
#   ('delivery', 'NN'),
#   ('plan', 'NN'),
#   ('.', '.')],
#  [('The', 'AT'),
#   ('Content', 'NN'),
#   ('Manager', 'NN-TL'),
#   ('also', 'RB'),
#   ('advises', 'VBZ'),
#   ('on', 'IN'),
#   ('creative', 'JJ'),
#   ('elements', 'NNS'),
#   ('such', 'JJ'),
#   ('as', 'CS'),
#   ('tone', 'NN'),
#   ('and', 'CC'),
#   ('style', 'NN'),
#   (',', ','),
#   ('empowering', 'VBG'),
#   ('client', 'NN'),
#   ('staff', 'NN'),
#   ('to', 'IN'),
#   ('create', 'VB'),
#   ('effective', 'JJ'),
#   ('web', 'NN'),
#   ('copy', 'NN'),
#   ('.', '.')],
#  [('With', 'IN'),
#   ('the', 'AT'),
#   ('Baby', 'NN-TL'),
#   ('Boom', 'NN'),
#   ('generation', 'NN'),
#   ('approaching', 'VBG'),
#   ('retirement', 'NN'),
#   (',', ','),
#   ('both', 'ABX'),
#   ('our', 'PP$'),
#   ('company', 'NN'),
#   ('and', 'CC'),
#   ('our', 'PP$'),
#   ('industry', 'NN'),
#   ('are', 'BER'),
#   ('experiencing', 'VBG'),
#   ('dramatic', 'JJ'),
#   ('growth', 'NN'),
#   ('!', '.')],
#  ...]

# %%
def freq_dist(sents):
    tagged_POS_sents = [item for sublist in sents for item in sublist]
    
    normed_tagged_words = [sent[0] for sent in tagged_POS_sents]
    
    # frequency distribution of first words in sentences
    return nltk.FreqDist(normed_tagged_words).items()

freq_dist(post.ngram_tags.values)
# Out:
# [(('The', 'AT'), 4168),
#  (('We', 'PPSS'), 4096),
#  (('-', 'IN'), 4093),
#  (('This', 'DT'), 2530),
#  (('Our', 'PP$'), 1860),
#  (('Ability', 'NN'), 1556),
#  (('You', 'PPSS'), 1548),
#  (('If', 'CS'), 1286),
#  (('Job', 'NP-TL'), 1211),
#  (('As', 'CS'), 1162),
#  (('In', 'IN'), 1117),
#  (('Experience', 'NN'), 941),
#  (('Work', 'NN'), 859),
#  (('*', 'NN'), 817),
#  (('Must', 'MD'), 797),
#  (('A', 'AT'), 769),
#  (('Provide', 'VB'), 748),
#  (('What', 'WDT'), 736),
#  (('Maintain', 'VB'), 707),
#  (('Strong', 'JJ'), 698),
#  (('Develop', 'VB'), 670),
#  (('Responsible', 'NN'), 634),
#  (('Ensure', 'VB'), 614),
#  (('Assist', 'VB'), 549),
#  (('Excellent', 'JJ'), 536),
#  (('Manage', 'VB'), 492),
#  (('Responsibilities', 'NN'), 491),
#  (('Position', 'NN'), 486),
#  (('Your', 'PP$'), 484),
#  (('&', 'CC'), 476),
#  (('For', 'IN'), 474),
#  (('At', 'IN'), 471),
#  (('With', 'IN'), 471),
#  (('and', 'CC'), 469),
#  (('Perform', 'VB'), 467),
#  (('Responsibilities:', 'NN'), 465),
#  (('All', 'ABN'), 405),
#  (('Are', 'BER'), 382),
#  (('Provides', 'VBZ'), 378),
#  (('Maintains', 'VBZ'), 369),
#  (('To', 'TO'), 356),
#  (('Ensures', 'VBZ'), 352),
#  (('Looking', 'VBG'), 340),
#  (('Assists', 'VBZ'), 325),
#  (('Knowledge', 'NN'), 323),
#  (('And', 'CC'), 321),
#  (('Do', 'DO'), 318),
#  ((')', ')'), 316),
#  (('Other', 'AP'), 307),
#  (('About', 'RB'), 297),
#  (('(', '('), 294),
#  (('Works', 'NNS'), 282),
#  (('May', 'MD'), 281),
#  (('Please', 'VB'), 278),
#  (('Required', 'VBN-HL'), 277),
#  (('Working', 'VBG-HL'), 275),
#  (('Essential', 'NN'), 269),
#  (('It', 'PPS'), 264),
#  (('Performs', 'VBZ'), 263),
#  (('Be', 'BE'), 261),
#  (('Prepare', 'VB'), 256),
#  (('No', 'AT'), 255),
#  (('Join', 'VB'), 253),
#  (('Identify', 'NN'), 250),
#  (('Participate', 'VB'), 249),
#  (('Sales', 'NNS'), 247),
#  (('Support', 'NN'), 247),
#  (('2', 'CD-HL'), 242),
#  (('Duties', 'NNS-TL'), 242),
#  (('Minimum', 'NN'), 240),
#  (('Manages', 'VBZ'), 237),
#  (('Develops', 'VBZ'), 235),
#  (('They', 'PPSS'), 232),
#  (('Lead', 'VB'), 231),
#  (('Maintaining', 'VBG'), 226),
#  (('Create', 'VB'), 222),
#  (('3', 'CD-HL'), 216),
#  (('Key', 'NN-HL'), 214),
#  (('Location', 'NN-HL'), 212),
#  (('These', 'DTS'), 211),
#  (('Coordinate', 'VB'), 209),
#  (('Retail', 'JJ-TL'), 207),
#  (('Additional', 'JJ'), 203),
#  (('Demonstrated', 'NN'), 203),
#  (('Compensation', 'NN'), 201),
#  (('Summary:', 'NN'), 201),
#  (('Providing', 'VBG'), 194),
#  (('1', 'CD-HL'), 190),
#  (('Able', 'NN'), 188),
#  (('JOB', 'NN'), 188),
#  (('Complete', 'VB'), 187),
#  (('Meet', 'VB'), 187),
#  (('Kelly', 'NP'), 186),
#  (('Review', 'VB'), 186),
#  (('Communicate', 'VB'), 185),
#  (('Build', 'VB'), 180),
#  (('Within', 'IN'), 180),
#  (('Top', 'JJS'), 176),
#  (('Handle', 'VB'), 173),
#  (('CyberCoders', 'NN'), 170),
#  (('Follow', 'VB'), 167),
#  (('Participates', 'VBZ'), 166),
#  (('Ref', 'NN'), 165),
#  (('Understand', 'VB'), 164),
#  (('Learn', 'VB-TL'), 163),
#  (('Have', 'HV'), 159),
#  (('Competitive', 'JJ'), 157),
#  (('Collaborate', 'NN'), 156),
#  (('Qualifications', 'NN'), 156),
#  (('Medical', 'JJ-TL-HL'), 151),
#  (('Conduct', 'VB'), 148),
#  (('Customer', 'NN'), 148),
#  (('Use', 'VB'), 147),
#  (('Apply', 'NN'), 146),
#  (('Requires', 'NN'), 145),
#  (('5', 'CD-HL'), 143),
#  (('Business', 'NN'), 142),
#  (('High', 'JJ'), 142),
#  (('Possess', 'NN'), 141),
#  (('Analyze', 'VB'), 139),
#  (('Company', 'NN'), 139),
#  (('GENERAL', 'NN'), 139),
#  (('Qualifications:', 'NN'), 139),
#  (('Bachelor', 'NN-TL'), 135),
#  (('Demonstrates', 'VBZ'), 134),
#  (('Prepares', 'VBZ'), 134),
#  (('Some', 'DTI'), 134),
#  (('Good', 'JJ'), 132),
#  (('Here', 'RB'), 132),
#  (('Training', 'NN'), 132),
#  (('Design', 'NN-HL'), 131),
#  (('Assisting', 'VBG'), 130),
#  (('Classification', 'NN'), 128),
#  (('Drive', 'NN-TL'), 128),
#  (('Current', 'JJ'), 127),
#  (('Supports', 'VBZ-HL'), 127),
#  (('Primary', 'JJ'), 126),
#  (('Paid', 'VBN-HL'), 125),
#  (('Establish', 'NN'), 124),
#  (('Actively', 'RB-HL'), 123),
#  (('An', 'AT'), 123),
#  (('Receive', 'VB'), 122),
#  (('Founded', 'VBN'), 121),
#  (('Proven', 'NN'), 121),
#  (('Monitor', 'VB'), 120),
#  (('o', 'NN'), 120),
#  (('Interact', 'VB'), 118),
#  (('Opportunity', 'NN'), 118),
#  (('Requirements:', 'NN'), 118),
#  (('How', 'WRB'), 116),
#  (('Effectively', 'RB'), 115),
#  (('Managing', 'VBG-TL'), 115),
#  (('Travel', 'NN'), 115),
#  (('the', 'AT'), 114),
#  (('4', 'CD-HL'), 113),
#  (('Education', 'NN'), 112),
#  (('San', 'NP'), 112),
#  (('Up', 'RP'), 112),
#  (('Take', 'VB'), 111),
#  (('to', 'IN-HL'), 111),
#  (('By', 'IN'), 110),
#  (('Conducts', 'NN'), 110),
#  (('Ensuring', 'VBG'), 110),
#  (('I', 'PPSS'), 110),
#  (('Act', 'NN-TL'), 109),
#  (('Desired', 'NN'), 109),
#  (('Educate', 'VB'), 109),
#  (('CHI', 'NN'), 108),
#  (('Leads', 'VBZ'), 108),
#  (('There', 'EX'), 107),
#  (('Candidates', 'NN'), 105),
#  (('Coordinates', 'VBZ'), 105),
#  (('Handling', 'VBG-TL'), 105),
#  (('Embassy', 'NN-TL'), 104),
#  (('Senior', 'JJ-TL'), 104),
#  (('Description', 'NN-TL'), 103),
#  (('Through', 'IN'), 103),
#  (('ESSENTIAL', 'NN'), 102),
#  (('Benefits', 'NN'), 101),
#  (('Establishes', 'NN'), 101),
#  (('Oversee', 'NN'), 100),
#  (('Will', 'MD'), 100),
#  (('Sell', 'VB'), 99),
#  (('Creates', 'VBZ'), 98),
#  (('Health', 'NN-TL'), 98),
#  (('Help', 'NN-HL'), 98),
#  (('Make', 'VB'), 98),
#  (('Why', 'WRB'), 98),
#  (('Maxim', 'NN'), 97),
#  (('Reviews', 'VBZ'), 97),
#  (('Whether', 'CS'), 97),
#  (('Additionally', 'RB'), 96),
#  (('Developing', 'VBG-TL'), 96),
#  (('Direct', 'JJ'), 96),
#  (('Previous', 'JJ'), 96),
#  (('Serving', 'VBG'), 96),
#  (('Find', 'VB'), 95),
#  (('So', 'RB'), 95),
#  (('401', 'NN'), 94),
#  (('Bachelors', 'NN'), 94),
#  (('Come', 'VB'), 94),
#  (('Financial', 'JJ-HL'), 94),
#  (('Call', 'VB'), 93),
#  (('Highly', 'QL'), 93),
#  (('Write', 'VB'), 93),
#  (('Basic', 'JJ-HL'), 92),
#  (('Pay', 'VB'), 92),
#  (('Advanced', 'JJ-TL'), 91),
#  (('Great', 'JJ'), 91),
#  (('Identifies', 'NN'), 91),
#  (('Completes', 'VBZ'), 90),
#  (('Monitors', 'VBZ'), 90),
#  (('Submit', 'NN'), 90),
#  (('When', 'WRB'), 90),
#  (('More', 'AP'), 89),
#  (('Partner', 'NN'), 89),
#  (('Project', 'NN-TL'), 89),
#  (('Full', 'JJ'), 88),
#  (('Implement', 'NN'), 88),
#  (('Macy', 'NN'), 88),
#  (('Youre', 'NN'), 88),
#  (('or', 'CC'), 88),
#  (('Keep', 'VB'), 87),
#  (('Now', 'RB'), 87),
#  (('Process', 'NN-TL'), 87),
#  (('Product', 'NN-HL'), 87),
#  (('Physical', 'JJ'), 86),
#  (('Summary', 'NN-HL'), 86),
#  (('Volt', 'NN'), 86),
#  (('for', 'CS'), 86),
#  (('Demonstrate', 'VB'), 85),
#  (('Overview:', 'NN'), 85),
#  (('6', 'CD-HL'), 84),
#  (('General', 'NN-TL'), 84),
#  (('Attend', 'NN'), 83),
#  (('Proficient', 'NN'), 83),
#  (('.', '.'), 82),
#  (('Each', 'DT'), 82),
#  (('Skills', 'NN'), 82),
#  (('Stay', 'VB'), 82),
#  (('Under', 'IN'), 82),
#  (('with', 'IN'), 82),
#  (('5+', 'NN'), 81),
#  (('Candidate', 'NN'), 81),
#  (('Collaborates', 'NN'), 81),
#  (('Thanks', 'NNS'), 81),
#  (('Solid', 'JJ'), 80),
#  (('Based', 'VBN'), 79),
#  (('Communication', 'NN'), 79),
#  (('Duration', 'NN'), 79),
#  (('Research', 'NN'), 79),
#  (('Track', 'NN-TL'), 79),
#  (('Esurance', 'NN'), 78),
#  (('Execute', 'NN'), 78),
#  (('Is', 'BEZ'), 78),
#  (('Nigel', 'NN'), 78),
#  (('Visit', 'VB'), 78),
#  (('Requirements', 'NNS-HL'), 77),
#  (('While', 'CS'), 77),
#  (('Prior', 'RB'), 76),
#  (('Start', 'VB'), 76),
#  (('AT', 'NN'), 75),
#  (('Adheres', 'VBZ'), 75),
#  (('CDL', 'NN'), 75),
#  (('Technical', 'JJ'), 75),
#  (('Contribute', 'VB'), 74),
#  (('Engage', 'NN'), 74),
#  (('Since', 'CS'), 74),
#  (('Evaluate', 'NN'), 73),
#  (('Even', 'RB'), 73),
#  (('Serve', 'VB'), 73),
#  (('a', 'AT'), 72),
#  (('Communicates', 'VBZ'), 71),
#  (('Define', 'VB-TL'), 71),
#  (('POSITION', 'NN'), 71),
#  (('Schedule', 'NN'), 71),
#  (('Weve', 'NN'), 71),
#  (('$', 'NN'), 70),
#  (('Bring', 'VB'), 70),
#  (('Clean', 'VB'), 70),
#  (('Currently', 'RB'), 70),
#  (('Every', 'AT'), 70),
#  (('From', 'IN'), 70),
#  (('Acts', 'NNS-TL'), 69),
#  (('Add', 'VB'), 69),
#  (('Experienced', 'NN'), 69),
#  (('Become', 'NN'), 68),
#  (('Bridgestone', 'NN'), 68),
#  (('Heres', 'NN'), 68),
#  (('Meeting', 'VBG'), 68),
#  (('Reports', 'NNS'), 68),
#  (('Respond', 'NN'), 68),
#  (('Specific', 'JJ'), 68),
#  (('[', ','), 68),
#  (('Get', 'VB'), 67),
#  (('Keywords:', 'NN'), 67),
#  (('L', 'NP'), 67),
#  (('Understanding', 'VBG'), 67),
#  (('1-3', 'CD'), 66),
#  (('3+', 'NN'), 66),
#  (('Service', 'NN'), 66),
#  (('That', 'DT'), 66),
#  (('Utilize', 'NN'), 66),
#  (('procedures', 'NNS'), 66),
#  (('-Responsible', 'NN'), 65),
#  (('Professional', 'JJ'), 65),
#  (('Store', 'NN-TL'), 65),
#  (('Team', 'NN-TL'), 64),
#  (('Understands', 'VBZ'), 64),
#  (('Utilizes', 'NN'), 64),
#  (('including', 'IN'), 64),
#  (('-Must', 'NN'), 63),
#  (('D', 'NP-HL'), 63),
#  (('Identifying', 'NN'), 63),
#  (('Of', 'IN'), 63),
#  (('Proficiency', 'NN'), 63),
#  (('Round', 'JJ-HL'), 63),
#  (('``', '``'), 63),
#  (('Following', 'VBG'), 62),
#  (('Management', 'NN-TL'), 62),
#  (('Account', 'NN'), 61),
#  (('Comprehensive', 'JJ'), 61),
#  (('Employee', 'NN-HL'), 61),
#  (('Facilitate', 'NN'), 61),
#  (('Multi-task', 'NN'), 61),
#  (('One', 'CD'), 61),
#  (('Provisions', 'NN'), 61),
#  (('Oversees', 'NN'), 60),
#  (('Building', 'NN-TL'), 59),
#  (('Data', 'NNS'), 59),
#  (('Java', 'NP'), 59),
#  (('People', 'NNS'), 59),
#  (('Were', 'BED'), 59),
#  (('Operate', 'NN'), 58),
#  (('Serves', 'VBZ'), 58),
#  (('is', 'BEZ'), 58),
#  (('#', 'NN'), 57),
#  (('Document', 'NN'), 57),
#  (('Entry', 'NN-TL'), 57),
#  (('Let', 'VB'), 57),
#  (('Revenue', 'NN-TL'), 57),
#  (('Achieve', 'NN'), 56),
#  (('England', 'NP'), 56),
#  (('Life', 'NN'), 56),
#  (('Reporting', 'NN'), 56),
#  (('Uses', 'NNS'), 56),
#  (('-Ensures', 'NN'), 55),
#  (('Download', 'NN'), 55),
#  (('EOE', 'NN'), 55),
#  (('Field', 'NN-TL'), 55),
#  (('Has', 'HVZ'), 55),
#  (('Plans', 'NNS'), 55),
#  (('Preferred', 'NN'), 55),
#  (('Proactively', 'NN'), 55),
#  (('Welcome', 'UH-TL'), 55),
#  (('in', 'IN'), 55),
#  (('Educating', 'NN'), 54),
#  (('Familiarity', 'NN'), 54),
#  (('Increase', 'NN-HL'), 54),
#  (('Keeps', 'NN'), 54),
#  (('Personal', 'JJ'), 54),
#  (('Silevo', 'NN'), 54),
#  (('Specifically', 'RB'), 54),
#  (('Today', 'NR'), 54),
#  (('Train', 'NN-TL'), 54),
#  (('Applies', 'NN'), 53),
#  (('Development', 'NN-HL'), 53),
#  (('During', 'IN'), 53),
#  (('Home', 'NN'), 53),
#  (('Ideal', 'JJ'), 53),
#  (('Interfacing', 'NN'), 53),
#  (('Software', 'NN'), 53),
#  (('Successful', 'JJ'), 53),
#  (('all', 'ABN'), 53),
#  (('iPad', 'NN'), 53),
#  (('Client', 'NN'), 52),
#  (('Evaluates', 'NN'), 52),
#  (('Generate', 'NN'), 52),
#  (('Install', 'VB'), 52),
#  (('Its', 'PP$'), 52),
#  (('Leadership', 'NN'), 52),
#  (('Send', 'VB'), 52),
#  (('Deliver', 'NN'), 51),
#  (('Employees', 'NNS'), 51),
#  (('Makes', 'VBZ'), 51),
#  (('Plan', 'NN-TL'), 51),
#  (('Supervises', 'NN'), 51),
#  (('T.', 'NP'), 51),
#  (('Top-notch', 'NN'), 51),
#  (('ability', 'NN'), 51),
#  (('App', 'NP'), 50),
#  (('Contact', 'VB-HL'), 50),
#  (('Guaranteed', 'NN'), 50),
#  (('Update', 'NN'), 50),
#  (('Weekend', 'NN'), 50),
#  (('Collect', 'NN'), 49),
#  (('Extensive', 'JJ'), 49),
#  (('First', 'RB'), 49),
#  (('New', 'JJ-TL'), 49),
#  (('Outside', 'RB'), 49),
#  (('Promote', 'NN'), 49),
#  (('Read', 'VB'), 49),
#  (('Supervise', 'NN'), 49),
#  (('Adhere', 'VB'), 48),
#  (('But', 'CC'), 48),
#  (('Flexible', 'NN'), 48),
#  (('Innovation', 'NN'), 48),
#  (('we', 'PPSS'), 48),
#  (('Continuously', 'NN'), 47),
#  (('Drives', 'NN'), 47),
#  (('Due', 'RB'), 47),
#  (('Effective', 'JJ'), 47),
#  (('On', 'IN'), 47),
#  (('Promotes', 'NN'), 47),
#  (('Set', 'VB'), 47),
#  (('Computer', 'NN'), 46),
#  (('Confidentiality', 'NN'), 46),
#  (('7', 'CD-HL'), 45),
#  (('Also', 'RB'), 45),
#  (('Associates', 'NNS-TL'), 45),
#  (('Bilingual', 'NN'), 45),
#  (('Conversant', 'NN'), 45),
#  (('Flexibility', 'NN'), 45),
#  (('Grow', 'NN'), 45),
#  (('MarketSource', 'NN'), 45),
#  (('Participating', 'VBG'), 45),
#  (('Rapid', 'NN'), 45),
#  (('Strategic', 'JJ-HL'), 45),
#  (('Weekly', 'JJ'), 45),
#  (('experience', 'NN'), 45),
#  (('10', 'CD-HL'), 44),
#  (('Assures', 'NN'), 44),
#  (('Open', 'VB'), 44),
#  (('Regional', 'JJ'), 44),
#  (('Relocation', 'NN'), 44),
#  (('Web', 'NN'), 44),
#  (('Week', 'NN'), 44),
#  (('http', 'NN'), 44),
#  (('2+', 'NN'), 43),
#  (('Big', 'JJ-TL'), 43),
#  (('Creating', 'VBG'), 43),
#  (('Monitoring', 'VBG'), 43),
#  (('Panda', 'NN'), 43),
#  (('Title', 'NN-TL'), 43),
#  (('Youll', 'NN'), 43),
#  (("'", "'"), 42),
#  (('Check', 'VB'), 42),
#  (('Contributes', 'NN'), 42),
#  (('Hilton', 'NP-TL'), 42),
#  (('RN', 'NN'), 42),
#  (('Recommend', 'NN'), 42),
#  (('providing', 'VBG'), 42),
#  (('you', 'PPSS'), 42),
#  (('Associate', 'NN-TL'), 41),
#  (('Builds', 'NN'), 41),
#  (('Career', 'NN'), 41),
#  (('Comfortable', 'NN'), 41),
#  (('Gain', 'NN-HL'), 41),
#  (('IT', 'NN'), 41),
#  (('Inside', 'RB'), 41),
#  (('Interface', 'NN'), 41),
#  (('Overall', 'NN'), 41),
#  (('RESPONSIBILITIES:', 'NN'), 41),
#  (('Rather', 'RB'), 41),
#  (('Responds', 'NN'), 41),
#  (('ensure', 'VB'), 41),
#  (('Answer', 'NN-HL'), 40),
#  (('Dental', 'NN'), 40),
#  (('Determine', 'VB'), 40),
#  (('Everyone', 'PN'), 40),
#  (('Expert', 'NN'), 40),
#  (('Follows', 'VBZ-TL'), 40),
#  (('Fully', 'NN'), 40),
#  (('See', 'VB'), 40),
#  (('Technology', 'NN-TL'), 40),
#  (('Then', 'RB'), 40),
#  (('Who', 'WPS'), 40),
#  (('--', '--'), 39),
#  (('Analyzes', 'VBZ'), 39),
#  (('BS', 'NN'), 39),
#  (('Documents', 'NNS-TL'), 39),
#  (('Generous', 'NN'), 39),
#  (('Local', 'JJ'), 39),
#  (('Operating', 'VBG'), 39),
#  (('Performing', 'VBG'), 39),
#  (('Qualified', 'NN'), 39),
#  (('Teamwork', 'NN'), 39),
#  (('Change', 'VB'), 38),
#  (('Citrix', 'NN'), 38),
#  (('Headquartered', 'NN'), 38),
#  (('Report', 'VB-HL'), 38),
#  (('Access', 'NN'), 37),
#  (('Daily', 'JJ-TL'), 37),
#  (('Deep', 'JJ'), 37),
#  (('Directs', 'NN'), 37),
#  (('Exceptional', 'JJ'), 37),
#  (('Manager', 'NN-TL'), 37),
#  (('Many', 'AP'), 37),
#  (('Present', 'JJ'), 37),
#  (('Reasonable', 'NN'), 37),
#  (('Special', 'JJ'), 37),
#  (('Taproot', 'NN'), 37),
#  (('-Experience', 'NN'), 36),
#  (('-Maintains', 'NN'), 36),
#  (('Assistant', 'NN'), 36),
#  (('Completing', 'VBG'), 36),
#  (('Description:', 'NN'), 36),
#  (('Executes', 'NN'), 36),
#  (('Facebook', 'NN'), 36),
#  (('Hotwire', 'NN'), 36),
#  (('Interviewing', 'VBG'), 36),
#  (('Just', 'RB'), 36),
#  (('Nearly', 'RB'), 36),
#  (('Organize', 'NN'), 36),
#  (('Planning', 'VBG-HL'), 36),
#  (('Preparing', 'VBG'), 36),
#  (('Quality', 'NN'), 36),
#  (('Troubleshoot', 'NN'), 36),
#  (('position', 'VB'), 36),
#  (('*******************************************************************************',
#    'NN'),
#   35),
#  (('He/she', 'NN'), 35),
#  (('Leverage', 'NN'), 35),
#  (('Over', 'IN'), 35),
#  (('Owner', 'NN'), 35),
#  (('RESPONSIBILITIES', 'NN'), 35),
#  (('Sequoia', 'NP-TL'), 35),
#  (('Sr.', 'NP'), 35),
#  (('Stock', 'NN'), 35),
#  (('Truck', 'NN'), 35),
#  (('Valid', 'NN'), 35),
#  (('of', 'IN'), 35),
#  (('Accountable', 'NN'), 34),
#  (('Advantage', 'NN'), 34),
#  (('Aid', 'NN-HL'), 34),
#  (('Communicating', 'VBG'), 34),
#  (('Day-to-day', 'NN'), 34),
#  (('Determines', 'NN'), 34),
#  (('Diagnoses', 'NNS-TL'), 34),
#  (('Driving', 'VBG'), 34),
#  (('Familiar', 'NN'), 34),
#  (('My', 'PP$'), 34),
#  (('Own', 'NN'), 34),
#  (('Parking', 'NN'), 34),
#  (('Salary', 'NN-HL'), 34),
#  (('Setting', 'VBG'), 34),
#  (('Thank', 'VB'), 34),
#  (('Wireless', 'NN'), 34),
#  ((':', ':'), 33),
#  (('Accurately', 'NN'), 33),
#  (('Administrative', 'JJ'), 33),
#  (('DUTIES', 'NN'), 33),
#  (('Entry-Level', 'NN'), 33),
#  (('Equal', 'JJ-HL'), 33),
#  (('Facilitates', 'NN'), 33),
#  (('Finance', 'NN-TL'), 33),
#  (('Independently', 'NN'), 33),
#  (('Major', 'JJ'), 33),
#  (('Represent', 'NN'), 33),
#  (('Robert', 'NP'), 33),
#  (('Should', 'MD'), 33),
#  (('as', 'CS'), 33),
#  (('at', 'IN'), 33),
#  (('sales', 'NNS'), 33),
#  (('www.HireLive.com', 'NN'), 33),
#  (('8', 'CD-HL'), 32),
#  (('9:00', 'CD'), 32),
#  (('Can', 'MD'), 32),
#  (('Coach', 'NN-HL'), 32),
#  (('Collaborating', 'NN'), 32),
#  (('College', 'NN'), 32),
#  (('Core', 'NN'), 32),
#  (('Distribute', 'NN'), 32),
#  (('Greet', 'NN'), 32),
#  (('Hit', 'NN-HL'), 32),
#  (('Industry', 'NN'), 32),
#  (('Interviews', 'NNS'), 32),
#  (('Move', 'NN'), 32),
#  (('Operations', 'NNS'), 32),
#  (('Part', 'NN-TL'), 32),
#  (('Researches', 'NN'), 32),
#  (('Retirement', 'NN-HL'), 32),
#  (('Supervisory', 'NN'), 32),
#  (('_________________________________________________________________________________',
#    'NN'),
#   32),
#  (('our', 'PP$'), 32),
#  (('Adequately', 'NN'), 31),
#  (('Assess', 'NN'), 31),
#  (('C.R', 'NN'), 31),
#  (('Creative', 'JJ'), 31),
#  (('Dignity', 'NN'), 31),
#  (('Helps', 'VBZ'), 31),
#  (('Initiates', 'NN'), 31),
#  (('Master', 'NN-TL'), 31),
#  (('Maximize', 'NN'), 31),
#  (('Mentor', 'NN'), 31),
#  (('Need', 'NN'), 31),
#  (('Passion', 'NN-TL'), 31),
#  (('Production', 'NN'), 31),
#  (('T', 'NP'), 31),
#  (('1-2', 'NN'), 30),
#  (('Applebee', 'NN'), 30),
#  (('Designs', 'NNS'), 30),
#  (('Enlistment', 'NN'), 30),
#  (('Expertise', 'NN'), 30),
#  (('Gate', 'NN-TL'), 30),
#  (('Individuals', 'NNS'), 30),
#  (('Outstanding', 'JJ'), 30),
#  (('Protect', 'NN'), 30),
#  (('Run', 'VB'), 30),
#  (('Swift', 'NP'), 30),
#  (('Takes', 'NN'), 30),
#  (('Tuition', 'NN'), 30),
#  (('it', 'PPS'), 30),
#  (('Built', 'VBN'), 29),
#  (('Click', 'NN'), 29),
#  (('Detail', 'NN-TL'), 29),
#  (('Implements', 'NN'), 29),
#  (('JLL', 'NN'), 29),
#  (('Marketing', 'VBG-HL'), 29),
#  (('McKesson', 'NN'), 29),
#  (('Monthly', 'NN-TL'), 29),
#  (('Network', 'NN'), 29),
#  (('Positive', 'JJ'), 29),
#  (('Results', 'NNS-HL'), 29),
#  (('Supporting', 'VBG-HL'), 29),
#  (('Test', 'VB'), 29),
#  (('Thorough', 'NN'), 29),
#  (('Watch', 'VB'), 29),
#  (('team', 'NN'), 29),
#  (('American', 'JJ'), 28),
#  (('Class', 'NN'), 28),
#  (('Coaches', 'NN'), 28),
#  (('Dedicated', 'NN'), 28),
#  (('Delivers', 'NN'), 28),
#  (('Discover', 'NN'), 28),
#  (('Education:', 'NN'), 28),
#  (('Enjoy', 'VB'), 28),
#  (('Insurance', 'NN-HL'), 28),
#  (('Interacts', 'VBZ'), 28),
#  (('Investigate', 'NN'), 28),
#  (('Leading', 'VBG'), 28),
#  (('Mileage', 'NN-HL'), 28),
#  (('Package', 'NN'), 28),
#  (('Recognized', 'NN'), 28),
#  (('Recruiting', 'NN'), 28),
#  (('Resolve', 'NN-TL'), 28),
#  (('Role', 'NN'), 28),
#  (('Roles', 'NNS'), 28),
#  (('Safety', 'NN'), 28),
#  (('Sunrun', 'NN'), 28),
#  (('THE', 'NN'), 28),
#  (('Territory', 'NN-TL'), 28),
#  (('Universal', 'JJ-TL'), 28),
#  (('Assure', 'NN'), 27),
#  (('Bloomingdale', 'NN'), 27),
#  (('California', 'NP'), 27),
#  (('Conducting', 'NN'), 27),
#  (('Consistently', 'NN'), 27),
#  (('Construction', 'NN'), 27),
#  (('Driven', 'VBN'), 27),
#  (('Enter', 'NN'), 27),
#  (('Most', 'AP'), 27),
#  (('Once', 'RB'), 27),
#  (('Produce', 'NN'), 27),
#  (('Registered', 'VBN'), 27),
#  (('Thats', 'NN'), 27),
#  (('by', 'IN'), 27),
#  (('development', 'NN'), 27),
#  (('provides', 'VBZ'), 27),
#  (('401K', 'NN'), 26),
#  (('Advise', 'VB-TL'), 26),
#  (('Average', 'NN'), 26),
#  (('Clearly', 'RB'), 26),
#  (('Commitment', 'NN'), 26),
#  (('Electrical', 'JJ-HL'), 26),
#  (('Food', 'NN'), 26),
#  (('Gather', 'VB-HL'), 26),
#  (('Hands-on', 'NN'), 26),
#  (('Hours', 'NNS'), 26),
#  (('Information', 'NN'), 26),
#  (('Integrity', 'NN'), 26),
#  (('Making', 'NN-TL'), 26),
#  (('Nice', 'JJ'), 26),
#  (('Ownership', 'NN'), 26),
#  (('Projects', 'NNS-TL'), 26),
#  (('Req', 'NN'), 26),
#  (('Treasure', 'NN-TL'), 26),
#  (('Very', 'QL'), 26),
#  (('Vision', 'NN-TL'), 26),
#  (('responsible', 'JJ'), 26),
#  (('so', 'RB'), 26),
#  (('work', 'NN'), 26),
#  (('Applicants', 'NN'), 25),
#  (('Assesses', 'NN'), 25),
#  (('Available', 'JJ'), 25),
#  (('Combining', 'NN'), 25),
#  (('Delivering', 'NN'), 25),
#  (('Drug', 'NN'), 25),
#  (('Inspect', 'VB'), 25),
#  (('Maintenance', 'NN'), 25),
#  (('Microsoft', 'NN'), 25),
#  (('Oracle', 'NN'), 25),
#  (('Performance', 'NN'), 25),
#  (('Play', 'VB'), 25),
#  (('Positions', 'NN'), 25),
#  (('Principle', 'NN-HL'), 25),
#  (('Program', 'NN'), 25),
#  (('Recognition', 'NN'), 25),
#  (('Record', 'NN-TL'), 25),
#  (('Vacation', 'NN'), 25),
#  (('Whatever', 'WDT'), 25),
#  (('however', 'WRB'), 25),
#  (('on', 'IN'), 25),
#  (('866-509-3555', 'NN'), 24),
#  (('Attends', 'NN'), 24),
#  (('Consistent', 'NN'), 24),
#  (('Consult', 'NN'), 24),
#  (('Engineering', 'VBG'), 24),
#  (('Fun', 'NN-TL'), 24),
#  (('He', 'PPS'), 24),
#  (('Hold', 'VB'), 24),
#  (('Immediate', 'NN'), 24),
#  (('Late', 'RB'), 24),
#  (('MS', 'NP-TL'), 24),
#  (('Manufacturing', 'VBG-TL'), 24),
#  (('Online', 'NN'), 24),
#  (('Partnering', 'NN'), 24),
#  (('Passionate', 'NN'), 24),
#  (('Regularly', 'NN'), 24),
#  (('SET', 'NN'), 24),
#  (('TEKsystems', 'NN'), 24),
#  (('Well', 'UH'), 24),
#  (('ensuring', 'VBG'), 24),
#  (('management', 'NN'), 24),
#  (('must', 'MD'), 24),
#  (('-Work', 'NN'), 23),
#  (('10+', 'NN'), 23),
#  (('401k', 'NN'), 23),
#  (('Attention', 'NN'), 23),
#  (('Background', 'NN'), 23),
#  (('Being', 'BEG'), 23),
#  (('Branch', 'NN'), 23),
#  (('Constantly', 'NN'), 23),
#  (('Establishing', 'NN'), 23),
#  (('Focus', 'NN'), 23),
#  (('Growth', 'NN-HL'), 23),
#  (('Healthcare', 'NN'), 23),
#  (('Location:', 'NN'), 23),
#  (('Masters', 'NNS-TL'), 23),
#  (('Number', 'VB'), 23),
#  (('Orchard', 'NN'), 23),
#  (('Partners', 'NN'), 23),
#  (('Processing', 'VBG-HL'), 23),
#  (('Recruit', 'NN'), 23),
#  (('Reviewing', 'VBG'), 23),
#  (('SUMMARY:', 'NN'), 23),
#  (('Safe', 'NN'), 23),
#  (('Summit', 'NN-TL'), 23),
#  (('Time', 'NN'), 23),
#  (('Verifies', 'NN'), 23),
#  (('provide', 'VB'), 23),
#  (('strong', 'JJ'), 23),
#  (('-Ability', 'NN'), 22),
#  (('Accounting', 'VBG'), 22),
#  (('Address', 'NN-TL'), 22),
#  (('Agile', 'NN'), 22),
#  (('Application', 'NN-TL'), 22),
#  (('Audit', 'NN'), 22),
#  (('Balancing', 'NN'), 22),
#  (('Bay', 'NN-TL'), 22),
#  (('Bending', 'NN'), 22),
#  (('Certified', 'NN'), 22),
#  (('Handles', 'NN'), 22),
#  (('Interested', 'VBN-HL'), 22),
#  (('Interview', 'VB'), 22),
#  (('Maximizing', 'VBG-HL'), 22),
#  (('Negotiate', 'NN'), 22),
#  (('Not', '*'), 22),
#  (('QUALIFICATIONS', 'NN'), 22),
#  (('Sets', 'NNS'), 22),
#  (('Skill', 'NN'), 22),
#  (('Sysco', 'NN'), 22),
#  (('Tax', 'NN-TL'), 22),
#  (('Transportation', 'NN-HL'), 22),
#  (('Visual', 'JJ'), 22),
#  (('from', 'IN'), 22),
#  (('maintain', 'VB'), 22),
#  (('staffing', 'VBG'), 22),
#  (('they', 'PPSS'), 22),
#  (('9', 'CD-HL'), 21),
#  (('CA', 'NN'), 21),
#  (('Connect', 'NN'), 21),
#  (('Continually', 'NN'), 21),
#  (('Contract', 'NN'), 21),
#  (('Database', 'NN'), 21),
#  (('Does', 'DOZ'), 21),
#  (('Driver', 'NN-TL'), 21),
#  (('EDUCATION', 'NN'), 21),
#  (('Education/Experience', 'NN'), 21),
#  (('Email', 'NN'), 21),
#  (('ICC', 'NN'), 21),
#  (('In-depth', 'NN'), 21),
#  (('Inventory', 'VB'), 21),
#  (('Last', 'AP'), 21),
#  (('Listen', 'VB'), 21),
#  (('National', 'JJ'), 21),
#  (('Observe', 'NN'), 21),
#  (('Opportunities', 'NNS-HL'), 21),
#  (('Optional', 'NN'), 21),
#  (('Organizes', 'NN'), 21),
#  (('Picking', 'NN'), 21),
#  (('RGIS', 'NN'), 21),
#  (('Recent', 'JJ'), 21),
#  (('Recommends', 'NN'), 21),
#  (('S', 'NP'), 21),
#  (('Self-motivated', 'NN'), 21),
#  (('Superior', 'JJ'), 21),
#  (('Their', 'PP$'), 21),
#  (('Two', 'CD'), 21),
#  (('UPS', 'NN'), 21),
#  (('Writes', 'VBZ-TL'), 21),
#  (('business', 'NN'), 21),
#  (('connect', 'VB'), 21),
#  (('develop', 'VB'), 21),
#  (('opportunities', 'NNS'), 21),
#  (('services', 'NNS'), 21),
#  (('-Provides', 'NN'), 20),
#  (('12', 'CD-HL'), 20),
#  (('After', 'IN'), 20),
#  (('AmTrust', 'NN'), 20),
#  (('Brown', 'NP'), 20),
#  (('Cash', 'NP'), 20),
#  (('Commercial', 'JJ'), 20),
#  (('Costco', 'NN'), 20),
#  (('Degree', 'NN'), 20),
#  (('Detailed', 'VBN'), 20),
#  (('Duties:', 'NN'), 20),
#  (('Expand', 'NN'), 20),
#  (('Full-Time/Part-Time*', 'NN'), 20),
#  (('Group', 'NN'), 20),
#  (('Implementing', 'NN'), 20),
#  (('Located', 'VBN'), 20),
#  (('Location*', 'NN'), 20),
#  (('Mathematical', 'JJ-TL'), 20),
#  (('Multiple', 'JJ'), 20),
#  (('No-touch', 'NN'), 20),
#  (('Obtain', 'NN'), 20),
#  (('Only', 'RB'), 20),
#  (('PHYSICAL', 'NN'), 20),
#  (('Position*', 'NN'), 20),
#  (('Repair', 'NN'), 20),
#  (('Schedules', 'NN'), 20),
#  (('Seasonal', 'JJ'), 20),
#  (('Seeking', 'VBG'), 20),
#  (('Selling', 'VBG'), 20),
#  (('Shift*', 'NN'), 20),
#  (('St.', 'NN-TL'), 20),
#  (('Strategies', 'NN'), 20),
#  (('Title*', 'NN'), 20),
#  (('Top-Tier', 'NN'), 20),
#  (('Tracks', 'NNS'), 20),
#  (('Translate', 'NN'), 20),
#  (('Verify', 'NN'), 20),
#  (('Walking', 'VBG'), 20),
#  (('be', 'BE'), 20),
#  (('extended', 'VBN'), 20),
#  (('managing', 'VBG'), 20),
#  (('***', 'NN'), 19),
#  (('1+', 'NN'), 19),
#  (('Because', 'CS'), 19),
#  (('Checks', 'NN'), 19),
#  (('Compile', 'NN'), 19),
#  (('Employment', 'NN-TL'), 19),
#  (('Family', 'NN'), 19),
#  (('Free', 'JJ'), 19),
#  (('Global', 'NN'), 19),
#  (('Includes', 'NN'), 19),
#  (('Individual', 'JJ'), 19),
#  (('Intermediate', 'JJ-TL'), 19),
#  (('Learning', 'NN'), 19),
#  (('Loomis', 'NP'), 19),
#  (('Operates', 'NN'), 19),
#  (('Or', 'CC'), 19),
#  (('PERFORMANCE', 'NN'), 19),
#  (('Practical', 'JJ-HL'), 19),
#  (('Proactive', 'NN'), 19),
#  (('Professionally', 'RB'), 19),
#  (('Promptly', 'RB'), 19),
#  (('Purpose:', 'NN'), 19),
#  (('Python', 'NN'), 19),
#  (('Ready', 'NN'), 19),
#  (('Seeks', 'VBZ-HL'), 19),
#  (('Services', 'NNS-HL'), 19),
#  (('Stable', 'NN'), 19),
#  (('Talent', 'NN'), 19),
#  (('Tea', 'NN'), 19),
#  (('Thursday', 'NR'), 19),
#  (('Troubleshooting', 'NN'), 19),
#  (('Typically', 'RB'), 19),
#  (('Upfront', 'NN'), 19),
#  (('Using', 'VBG'), 19),
#  (('assist', 'VB'), 19),
#  (('proactively', 'NN'), 19),
#  (('provided', 'VBN'), 19),
#  (('will', 'MD'), 19),
#  (('working', 'VBG'), 19),
#  (('-Assists', 'NN'), 18),
#  (('-Monitors', 'NN'), 18),
#  (('ABOUT', 'NN'), 18),
#  (('APPLY', 'NN'), 18),
#  (('Analytical', 'JJ'), 18),
#  (('Arts', 'NNS-TL'), 18),
#  (('Assemble', 'VB'), 18),
#  (('Automotive', 'NN'), 18),
#  (('CAAP', 'NN'), 18),
#  (('CR', 'NN'), 18),
#  (('Carry', 'NN'), 18),
#  (('Collects', 'NN'), 18),
#  (('Cushman', 'NP'), 18),
#  (('DNV', 'NN'), 18),
#  (('Directly', 'RB'), 18),
#  (('E', 'NP-HL'), 18),
#  (('Experience:', 'NN'), 18),
#  (('Fosters', 'NN'), 18),
#  (('Hands', 'NNS'), 18),
#  (('Initiate', 'NN'), 18),
#  (('Items', 'NNS-TL'), 18),
#  (('JavaScript', 'NN'), 18),
#  (('Linux', 'NN'), 18),
#  (('Meets', 'VBZ-TL'), 18),
#  (('Moving', 'VBG'), 18),
#  (('NO', 'NN'), 18),
#  (('Operational', 'JJ'), 18),
#  (('Plus', 'IN'), 18),
#  (('RadNet', 'NN'), 18),
#  (('SUMMARY', 'NN'), 18),
#  (('Scion', 'NN'), 18),
#  (('SiempreTax+', 'NN'), 18),
#  (('Solar', 'JJ'), 18),
#  (('Sr', 'NN'), 18),
#  (('Troubleshoots', 'NN'), 18),
#  (('Upon', 'IN'), 18),
#  (('WHAT', 'NN'), 18),
#  (('Walnut', 'NN'), 18),
#  (('Z', 'NN'), 18),
#  (('ZipRealty', 'NN'), 18),
#  (('customer', 'NN'), 18),
#  (('manage', 'VB'), 18),
#  (('**', 'NN'), 17),
#  (('Administer', 'NN'), 17),
#  (('BA/BS', 'NN'), 17),
#  (('Base', 'NN-TL'), 17),
#  (('Clinical', 'NN'), 17),
#  (('Completion', 'NN-TL'), 17),
#  (('Complies', 'NN'), 17),
#  (('Concord', 'NP'), 17),
#  (('Control', 'NN'), 17),
#  (('Crowe', 'NN'), 17),
#  (('Delivery', 'NN-TL'), 17),
#  (('Department', 'NN'), 17),
#  (('Diagnose', 'NN'), 17),
#  (('Duration:', 'NN'), 17),
#  (('Established', 'NN'), 17),
#  (('Explaining', 'NN'), 17),
#  (('Furthermore', 'RB'), 17),
#  (('Heavy', 'JJ-HL'), 17),
#  (('Hertz', 'NP'), 17),
#  (('Independent', 'JJ'), 17),
#  (('Internal', 'JJ'), 17),
#  (('Know', 'VB'), 17),
#  (('La', 'NP'), 17),
#  (('Law', 'NN'), 17),
#  (('Love', 'NN'), 17),
#  (('M', 'NN'), 17),
#  (('Office', 'NN'), 17),
#  (('Ongoing', 'NN'), 17),
#  (('Part-time', 'JJ'), 17),
#  (('Quick', 'RB'), 17),
#  (('RESPECTED', 'NN'), 17),
#  (('Relationship', 'NN-HL'), 17),
#  (('Represents', 'NN'), 17),
#  (('Security', 'NN-TL'), 17),
#  (('Shift', 'NN'), 17),
#  (('Social', 'JJ'), 17),
#  (('Sports', 'NNS-TL'), 17),
#  (('State', 'NN'), 17),
#  (('Structured', 'NN'), 17),
#  (('TOOLS', 'NN'), 17),
#  (('UPWARD', 'NN'), 17),
#  (('Unique', 'JJ'), 17),
#  (('Updates', 'NN'), 17),
#  (('Variety', 'NN-TL'), 17),
#  (('Vendor', 'NN'), 17),
#  (('additional', 'JJ'), 17),
#  (('benefits', 'NNS'), 17),
#  (('its', 'PP$'), 17),
#  (('3-5', 'CD'), 16),
#  (('Achieving', 'VBG-HL'), 16),
#  (('Active', 'JJ'), 16),
#  (('Architect', 'NN-TL'), 16),
#  (('Asynchrony', 'NN'), 16),
#  ...]

# %%
post.to_pickle(path.join(pardir, 'data','preprocessed_text_nov24.pkl'))
