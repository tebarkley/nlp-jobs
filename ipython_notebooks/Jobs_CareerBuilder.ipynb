# %% [markdown]
# # Getting Data from JobSearch CB API

# %%
import pandas as pd
import requests
import xmltodict
import json
from os import path, pardir
import math
import settings
import sys
import datetime
from pandas.io.json import json_normalize

# %% [markdown]
# Read in the dataframe from the jobsearch

# %%
master_df = pd.io.pickle.read_pickle(path.join(pardir, 'data', 'SF_jobs_Nov11_dedup.pkl'))
master_df.head()
# Out:
#                         ApplyRequirements           City  \
# 0  {u'ApplyRequirement': u'CanBulkApply'}  San Francisco
# 1    {u'ApplyRequirement': u'IsExternal'}  San Francisco
# 2    {u'ApplyRequirement': u'IsExternal'}  San Francisco
# 3    {u'ApplyRequirement': u'IsExternal'}           None
# 4    {u'ApplyRequirement': u'IsExternal'}  San Francisco
#
#                     Company           CompanyDID  \
# 0  Largent & Associates LLC  chs3sx6c15lnf4hrq6q
# 1                      None                 None
# 2                    Sunrun  chq010614mz6j2s07v4
# 3        The Master's Touch  chm2yn5wgb2c3nx62ry
# 4                    Sunrun  chq010614mz6j2s07v4
#
#                                    CompanyDetailsURL  \
# 0  http://www.careerbuilder.com/jobs/company/chs3...
# 1                                               None
# 2  http://www.careerbuilder.com/jobs/company/chq0...
# 3  http://www.careerbuilder.com/jobs/company/chm2...
# 4  http://www.careerbuilder.com/jobs/company/chq0...
#
#                                      CompanyImageURL                  DID  \
# 0  http://emj.icbdr.com/mediamanagement/zt/myk6ss...  JHL4PY5YCYWRKR5SR63
# 1                                               None  J3H6HZ6HJ4RMVWCG7HZ
# 2  http://emj.icbdr.com/mediamanagement/l8/mr80c6...  J3H3BC6PGK27KG7YZLN
# 3  http://emj.icbdr.com/mediamanagement/vm/mrk6jt...  JHR71P6BGWQYFCSN5ZW
# 4  http://emj.icbdr.com/mediamanagement/l8/mr80c6...  J3H5FV6N2RZXBQKJ2ZZ
#
#                                    DescriptionTeaser DisplayCity Distance  \
# 0  Divisional Sales Director, Western Region Are ...        None   Nearby
# 1  Field Training Specialist, L&D Position Summar...        None   Nearby
# 2  FIELD MARKETING TRAINER This job reports to th...        None   Nearby
# 3  Click on the LEARN MORE button to get the deta...         NaN     None
# 4  Director, FP&A – Sales and Marketing As a rapi...        None   Nearby
#
#    EducationRequired       EmploymentType ExperienceRequired JobBrandingIcons  \
# 0  Bachelor's Degree            Full-Time      Not Specified             None
# 1  Bachelor's Degree            Full-Time      Not Specified             None
# 2      Not Specified            Full-Time      Not Specified             None
# 3      Not Specified  Full-Time/Part-Time      Not Specified             None
# 4  Bachelor's Degree            Full-Time      Not Specified             None
#
#                                        JobDetailsURL  \
# 0  http://api.careerbuilder.com/v1/joblink?Tracki...
# 1  http://api.careerbuilder.com/v1/joblink?Tracki...
# 2  http://api.careerbuilder.com/v1/joblink?Tracki...
# 3  http://api.careerbuilder.com/v1/joblink?Tracki...
# 4  http://api.careerbuilder.com/v1/joblink?Tracki...
#
#                                        JobServiceURL  \
# 0  https://api.careerbuilder.com/v1/job?DID=JHL4P...
# 1  https://api.careerbuilder.com/v1/job?DID=J3H6H...
# 2  https://api.careerbuilder.com/v1/job?DID=J3H3B...
# 3  https://api.careerbuilder.com/v1/job?DID=JHR71...
# 4  https://api.careerbuilder.com/v1/job?DID=J3H5F...
#
#                                             JobTitle            Location  \
# 0          Divisional Sales Director, Western Region  CA - San Francisco
# 1                          Field Training Specialist  CA - San Francisco
# 2      Instructional Designer, Retail Sales Training  CA - San Francisco
# 3  Stop Looking Now! Imagine the Freedom of Final...       US-Nationwide
# 4               Director, FP&A - Sales and Marketing  CA - San Francisco
#
#   LocationLatitude LocationLongitude
# 0         37.77712        -122.41964 ...
# 1         37.77712        -122.41964 ...
# 2         37.77712        -122.41964 ...
# 3              0.0               0.0 ...
# 4         37.77712        -122.41964 ...
#
# [5 rows x 28 columns]

# %% [markdown]
# Get the job descriptions that we've already called

# %%
obtained_jobs = pd.io.pickle.read_pickle(path.join(pardir, 'data', 'job_descriptions.pkl'))
obtained_jobs.head()
# Out:
#                                             ApplyURL BasicJobBranding  \
# 0  http://api.careerbuilder.com/v1/application/ap...              NaN
# 1  http://api.careerbuilder.com/v1/application/ap...              NaN
# 2  http://api.careerbuilder.com/v1/application/ap...              NaN
# 3  http://api.careerbuilder.com/v1/application/ap...              NaN
# 4  http://api.careerbuilder.com/v1/application/ap...              NaN
#
#     BeginDate                         BlankApplicationServiceURL  \
# 0  10/12/2014  http://api.careerbuilder.com/v1/application/bl...
# 1  10/12/2014  http://api.careerbuilder.com/v1/application/bl...
# 2  10/12/2014  http://api.careerbuilder.com/v1/application/bl...
# 3  10/12/2014  http://api.careerbuilder.com/v1/application/bl...
# 4  10/12/2014  http://api.careerbuilder.com/v1/application/bl...
#
#                                     Categories    CategoriesCodes  \
# 0    Sales,  Business Development,  Management  JN011,JN019,JN037
# 1                                     Training              JN032
# 2                                        Sales              JN011
# 3  Construction,  Sales,  Business Opportunity  JN043,JN011,JN059
# 4                                        Sales              JN011
#
#                     Company           CompanyDID  \
# 0  Largent & Associates LLC  CHS3SX6C15LNF4HRQ6Q
# 1                       NaN                  NaN
# 2                    Sunrun  CHQ010614MZ6J2S07V4
# 3        The Master's Touch  CHM2YN5WGB2C3NX62RY
# 4                    Sunrun  CHQ010614MZ6J2S07V4
#
#                                    CompanyDetailsURL  \
# 0  http://www.careerbuilder.com/jobs/company/chs3...
# 1                                                NaN
# 2  http://www.careerbuilder.com/jobs/company/chq0...
# 3  http://www.careerbuilder.com/jobs/company/chm2...
# 4  http://www.careerbuilder.com/jobs/company/chq0...
#
#                                      CompanyImageURL  \
# 0  http://emj.icbdr.com/MediaManagement/2G/MVC6X3...
# 1                                                NaN
# 2  http://emj.icbdr.com/MediaManagement/G0/MVM81W...
# 3  http://emj.icbdr.com/MediaManagement/DN/MVD3D5...
# 4  http://emj.icbdr.com/MediaManagement/G0/MVM81W...
#
#                                  CompanyJobSearchURL  \
# 0  http://www.careerbuilder.com/jobs/company/chs3...
# 1                                                NaN
# 2  http://www.careerbuilder.com/jobs/company/chq0...
# 3  http://www.careerbuilder.com/jobs/company/chm2...
# 4  http://www.careerbuilder.com/jobs/company/chq0...
#
#                                  ContactInfoEmailURL ContactInfoFax  \
# 0  http://www.careerbuilder.com/jobseeker/applyon...            NaN
# 1  http://www.careerbuilder.com/jobseeker/applyon...            NaN
# 2  http://www.careerbuilder.com/jobseeker/applyon...            NaN
# 3  http://www.careerbuilder.com/jobseeker/applyon...            NaN
# 4  http://www.careerbuilder.com/jobseeker/applyon...            NaN
#
#         ContactInfoName ContactInfoPhone CustomApplyType                  DID  \
# 0  Largent & Associates              NaN          CANONE  JHL4PY5YCYWRKR5SR63
# 1                   NaN              NaN          CANONE  J3H6HZ6HJ4RMVWCG7HZ
# 2                   NaN              NaN          CANONE  J3H3BC6PGK27KG7YZLN
# 3         Dustin Nelson     623-889-0313          CANONE  JHR71P6BGWQYFCSN5ZW
# 4                   NaN              NaN          CANONE  J3H5FV6N2RZXBQKJ2ZZ
#
#   DegreeRequired DegreeRequiredCode        DisplayJobID
# 0  4 Year Degree               DR32  495 Sales Dir West ...
# 1  4 Year Degree               DR32            US-27377 ...
# 2  Not Specified               DRNS                1069 ...
# 3  Not Specified               DRNS                 NaN ...
# 4  4 Year Degree               DR32                 732 ...
#
# [5 rows x 66 columns]

# %% [markdown]
# Create sets of the job ids already found to have been invalid or already obtained

# %%
invalid = set(pd.io.pickle.read_pickle(path.join(pardir, 'data', 'invalid_job_ids.pkl')))
obtained = set([job_id.encode('ascii', 'ignore') for job_id in obtained_jobs.DID])

# %% [markdown]
# Create a list of job ids for which we still need to obtain descriptions

# %%
job_ids = [job_id.encode('ascii', 'ignore') for job_id in master_df.DID]
job_ids = [job_id for job_id in job_ids if job_id not in invalid and job_id not in obtained]

# %%
def get_jobs(num_jobs=500, invalid=invalid):
    daily_jobs_call = pd.DataFrame()
    for i, job_id in enumerate(job_ids):
        parameters = {'DeveloperKey': settings.CB_API_KEY, 
                      'DID': job_id}
        r = requests.get('http://api.careerbuilder.com/v3/job/', params=parameters)
        o = xmltodict.parse(r.content)
        j = json.dumps(o)
        raw_df = pd.read_json(j)
        if 'Job' in raw_df.index:
            new_df = json_normalize(raw_df.T.Job)
            daily_jobs_call = pd.concat([daily_jobs_call, new_df], ignore_index=True)
        else:
            invalid.add(job_id)
        if i == num_jobs - 1:
            break
    return daily_jobs_call, invalid

# %%
jobs, invalid = get_jobs(num_jobs=5)

# %%
invalid_series = pd.Series(list(invalid))
invalid_series.to_pickle(path.join(pardir, 'data', 'invalid_job_ids.pickle'))

# %%
filetime = str(datetime.datetime.now()).replace(' ', '_').replace(':', '_').replace('.','_').replace('-','_')[:16]
jobs.to_pickle(path.join(pardir, 'data','jobs_call_' + filetime + '.pkl'))

# %%
all_jobs = pd.concat([obtained_jobs, jobs], ignore_index=True)
all_jobs.to_pickle(path.join(pardir, 'data', 'job_descriptions.pkl'))
